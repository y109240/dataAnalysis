# %% [markdown]
# # 미니프로젝트
# - 서울시 반려동물등록 분포에 대해서 알아보자
# - 동물등록분포와 수업시간에 해봤던 인구분포와의 관계

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

# %%
강남구 = pd.read_csv('미니프로젝트_데이터/강남구.csv', encoding='cp949')
강남구 = 강남구[['동명', '동물 등록수']]
강남구.columns = ['동명', '등록동물수']
강남구
# Out:
#       동명  등록동물수
# 0    개포동   3189
# 1    논현동   3890
# 2    대치동   4209
# 3    도곡동   2877
# 4    삼성동   2902
# 5    세곡동    641
# 6    수서동    992
# 7    신사동    874
# 8    역삼동   5096
# 9    율현동    159
# 10   일원동   1755
# 11   자곡동    898
# 12   청담동   2005
# 13  압구정동   1884

# %%
강동구 = pd.read_csv('미니프로젝트_데이터/강동구.csv', encoding='cp949')
강동구['등록동물수'] = 강동구.RFID내장형 + 강동구.RFID외장형 + 강동구.인식표
강동구 = 강동구[['읍면동', '등록동물수']]
강동구.columns = ['동명', '등록동물수']
강동구
# Out:
#     동명  등록동물수
# 0   길동   2019
# 1  강일동    814
# 2  고덕동   1299
# 3  둔촌동   1524
# 4  명일동   1534
# 5  상일동    936
# 6  성내동   2971
# 7  암사동   3083
# 8  천호동   4101

# %%
강북구 = pd.read_csv('미니프로젝트_데이터/강북구.csv', encoding='cp949')
강북구['등록동물수'] = 강북구['RFID종류 내장형'] + 강북구['RFID종류 외장형'] + 강북구['RFID종류 인식표']
강북구 = 강북구[['읍면동(법정동)', '등록동물수']].iloc[:4, ]
강북구.columns = ['동명', '등록동물수']
강북구
# Out:
#     동명   등록동물수
# 0   번동  2602.0
# 1  미아동  6655.0
# 2  수유동  5735.0
# 3  우이동   660.0

# %%
강서구 = pd.read_csv('미니프로젝트_데이터/강서구.csv', encoding='cp949')
강서구['고양이등록수'].fillna(0, inplace=True) # 결측치 변환
강서구['등록동물수'] = 강서구.개등록수 + 강서구.고양이등록수
강서구 = 강서구[['법정동', '등록동물수']]
강서구.columns = ['동명', '등록동물수']
강서구
# Out:
#       동명    등록동물수
# 0    가양동   2174.0
# 1    개화동    159.0
# 2    공항동   1056.0
# 3    등촌동   3363.0
# 4    마곡동   1397.0
# 5    방화동   3549.0
# 6    염창동   1760.0
# 7    오쇠동      3.0
# 8    화곡동  12567.0
# 9   내발산동   1973.0
# 10  외발산동     54.0

# %%
관악구 = pd.read_csv('미니프로젝트_데이터/관악구.csv', encoding='cp949')
관악구 = 관악구[['읍면동명', '등록동물수']]
관악구.columns = ['동명', '등록동물수']
관악구
# Out:
#     동명  등록동물수
# 0  남현동    871
# 1  봉천동   9601
# 2  신림동  14555

# %%
광진구 = pd.read_csv('미니프로젝트_데이터/광진구.csv', encoding='cp949')
광진구['등록동물수'] = 광진구['RFID종류(내장형)'] + 광진구['RFID종류(외장형)'] + 광진구['RFID종류(인식표)']
광진구 = 광진구[['읍면동(법정동)', '등록동물수']]
광진구.columns = ['동명', '등록동물수']
광진구
# Out:
#     동명  등록동물수
# 0   능동    583
# 1  광장동   1968
# 2  구의동   5011
# 3  군자동   1155
# 4  노유동      2
# 5  자양동   5917
# 6  중곡동   5080
# 7  화양동   1318

# %%
구로구 = pd.read_csv('미니프로젝트_데이터/구로구.csv', encoding='cp949')
구로구['등록동물수'] = 구로구['내장형(RFID)'] + 구로구['외장형(RFID)'] + 구로구['인식표']
구로구 = 구로구[['법정동', '등록동물수']]
구로구.columns = ['동명', '등록동물수']
구로구
# Out:
#      동명  등록동물수
# 0    궁동    817
# 1    항동    579
# 2   개봉동   5006
# 3   고척동   3047
# 4   구로동   6726
# 5   오류동   2536
# 6   온수동    468
# 7   천왕동    757
# 8  가리봉동    655
# 9  신도림동   1847

# %%
금천구 = pd.read_csv('미니프로젝트_데이터/금천구.csv', encoding='cp949')
금천구 = 금천구[['법정동', '개체수(전체)']]
금천구.columns = ['동명', '등록동물수']
금천구
# Out:
#     동명  등록동물수
# 0  가산동   1139
# 1  독산동   6044
# 2  시흥동   6369

# %%
노원구 = pd.read_csv('미니프로젝트_데이터/노원구.csv', encoding='cp949')
노원구['등록동물수'] = 노원구['RFID종류(내장형)'] + 노원구['RFID종류(외장형)'] + 노원구['RFID종류(인식표)']
노원구 = 노원구[['읍면동(법정동)', '등록동물수']].iloc[-6:-1, ]
노원구.columns = ['동명', '등록동물수']
노원구
# Out:
#      동명  등록동물수
# 49  하계동    344
# 50  공릉동    163
# 51  상계동    567
# 52  월계동    185
# 53  중계동    261

# %%
도봉구 = pd.read_csv('미니프로젝트_데이터/도봉구.csv', encoding='cp949')
도봉구.columns = ['동명', '등록동물수']
도봉구['등록동물수'] = 도봉구.등록동물수.str.replace(",","").str.replace("건", "").astype('int64')
도봉구
# Out:
#      동명  등록동물수
# 0   쌍문동   3717
# 1   방학동   3481
# 2   도봉동   2081
# 3  창  동   5397

# %%
동대문구 = pd.read_csv('미니프로젝트_데이터/동대문구.csv', encoding='cp949')
동대문구['등록동물수'] = 동대문구.등록형태_내장형RFID + 동대문구.등록형태_외장형RFID + 동대문구.등록형태_인식표RFID
동대문구 = 동대문구[['읍면동(법정동)', '등록동물수']]
동대문구.columns = ['동명', '등록동물수']
동대문구
# Out:
#      동명  등록동물수
# 0   신설동    254
# 1   용두동   1692
# 2   이문동   2671
# 3   장안동   4562
# 4   전농동   2413
# 5   제기동   1471
# 6   회기동    500
# 7   휘경동   1835
# 8  답십리동   3129
# 9  청량리동   1038

# %%
동작구 = pd.read_csv('미니프로젝트_데이터/동작구.csv', encoding='cp949')
동작구 = 동작구[['법정동', '반려동물총계']]
동작구.columns = ['동명', '등록동물수']
동작구
# Out:
#      동명  등록동물수
# 0    본동    585
# 1   대방동   1979
# 2   동작동    342
# 3   사당동   5126
# 4   상도동   6119
# 5   흑석동   1702
# 6  상도1동    495
# 7  노량진동   1509
# 8  신대방동   2438

# %%
마포구 = pd.read_csv('미니프로젝트_데이터/마포구.csv', encoding='cp949')
마포구 = 마포구[['법정동', '합계']][:-1]
마포구.columns = ['동명', '등록동물수']
마포구
# Out:
#       동명   등록동물수
# 0     중동   634.0
# 1    공덕동  1505.0
# 2    구수동    62.0
# 3    당인동    92.0
# 4    대흥동   798.0
# 5    도화동  1252.0
# 6    동교동   337.0
# 7    마포동   158.0
# 8    망원동  2954.0
# 9    상수동   534.0
# 10   상암동  1777.0
# 11   서교동  2770.0
# 12   성산동  3373.0
# 13   신수동   763.0
# 14   신정동    61.0
# 15   아현동  1327.0
# 16   연남동  1303.0
# 17   염리동   881.0
# 18   용강동   384.0
# 19   창전동   786.0
# 20   토정동    75.0
# 21   하중동   106.0
# 22   합정동  1435.0
# 23   현석동   251.0
# 24  노고산동   496.0
# 25  신공덕동   672.0

# %%
서대문구 = pd.read_csv('미니프로젝트_데이터/서대문구.csv', encoding='cp949')
서대문구
# Out:
#      연도  누적등록수(마리)         기준일
# 0  2019      14090  2021-12-31
# 1  2020      15232  2021-12-31
# 2  2021      16944  2021-12-31

# %%
성동구 = pd.read_csv('미니프로젝트_데이터/성동구.csv', encoding='cp949')
성동구 = 성동구[['법정동', '등록수']]
성동구.columns = ['동명', '등록동물수']
성동구
# Out:
#        동명  등록동물수
# 0     도선동    291
# 1     마장동   1144
# 2     사근동    352
# 3     송정동    735
# 4     옥수동   1739
# 5     용답동    831
# 6     응봉동    983
# 7     행당동   2498
# 8     홍익동    224
# 9   금호동1가   1124
# 10  금호동2가    793
# 11  금호동3가    844
# 12  금호동4가    929
# 13  성수동1가   2285
# 14  성수동2가   1791
# 15  상왕십리동    256
# 16  하왕십리동   1852

# %%
성북구 = pd.read_csv('미니프로젝트_데이터/성북구.csv', encoding='cp949')
성북구 = 성북구[['동', '합계']]
성북구.columns = ['동명', '등록동물수']
성북구
# Out:
#         동명  등록동물수
# 0      길음동   2005
# 1      돈암동   1978
# 2      석관동   1573
# 3      성북동   1062
# 4      장위동   3106
# 5      정릉동   3970
# 6      종암동   1748
# 7     상월곡동    507
# 8     하월곡동   2005
# 9    동선동1가     57
# 10   동선동2가    107
# 11   동선동3가    136
# 12   동선동4가    145
# 13   동선동5가     91
# 14   보문동1가     88
# 15   보문동2가    127
# 16   보문동3가    149
# 17   보문동4가     47
# 18   보문동5가    100
# 19   보문동6가    301
# 20   보문동7가     34
# 21   삼선동1가    296
# 22   삼선동2가    330
# 23   삼선동3가    240
# 24   삼선동4가    114
# 25   삼선동5가    205
# 26   성북동1가    136
# 27   안암동1가    162
# 28   안암동2가    126
# 29   안암동3가    253
# 30   안암동4가     51
# 31   안암동5가    118
# 32  동소문동1가     69
# 33  동소문동2가     74
# 34  동소문동3가      7
# 35  동소문동4가    112
# 36  동소문동5가     44
# 37  동소문동6가     84
# 38  동소문동7가    120

# %%
송파구 = pd.read_csv('미니프로젝트_데이터/송파구.csv', encoding='cp949')
송파구 = 송파구[['법정동명', '등록동물수(마리)']]
송파구.columns = ['동명', '등록동물수']
송파구
# Out:
#      동명  등록동물수
# 0   가락동   3195
# 1   거여동   1531
# 2   마천동   1728
# 3   문정동   3233
# 4   방이동   3056
# 5   삼전동   1887
# 6   석촌동   1862
# 7   송파동   2152
# 8   신천동   1680
# 9   오금동   1657
# 10  잠실동   5255
# 11  장지동   1551
# 12  풍납동   1701

# %%
영등포구 = pd.read_csv('미니프로젝트_데이터/영등포구.csv', encoding='cp949')
영등포구 = 영등포구[['읍면동(법정동)', '동물등록수합계(마리)']]
영등포구.columns = ['동명', '등록동물수']
영등포구
# Out:
#         동명  등록동물수
# 0      당산동    322
# 1      대림동   2725
# 2      도림동   1040
# 3      신길동   5303
# 4     여의도동   2064
# 5     영등포동    721
# 6    당산동1가    403
# 7    당산동2가    277
# 8    당산동3가    509
# 9    당산동4가    563
# 10   당산동5가    607
# 11   당산동6가    209
# 12   문래동1가     12
# 13   문래동2가     62
# 14   문래동3가    751
# 15   문래동4가     96
# 16   문래동5가    230
# 17   문래동6가    485
# 18   양평동1가    269
# 19   양평동2가    356
# 20   양평동3가    535
# 21   양평동4가    335
# 22   양평동5가    314
# 23   양평동6가    290
# 24  영등포동1가    149
# 25  영등포동2가    227
# 26  영등포동3가     94
# 27  영등포동4가    116
# 28  영등포동5가    116
# 29  영등포동6가    112
# 30  영등포동7가    433
# 31  영등포동8가    239

# %%
용산구 = pd.read_csv('미니프로젝트_데이터/용산구.csv', encoding='cp949')
용산구 = 용산구[['법정동', '반려동물수']]
용산구.columns = ['동명', '등록동물수']
용산구
# Out:
#        동명  등록동물수
# 0     갈월동    172
# 1     남영동     36
# 2     도원동    340
# 3     동자동    238
# 4     문배동    385
# 5     보광동   1457
# 6     산천동    497
# 7     서계동    331
# 8     신계동    167
# 9     신창동    143
# 10    용문동    336
# 11    이촌동   2432
# 12    주성동     80
# 13    청암동    135
# 14    한남동   2481
# 15    효창동    645
# 16    후암동   1312
# 17   동빙고동    502
# 18   서빙고동    427
# 19   이태원동   2487
# 20  용산동2가   1076
# 21  용산동3가     14
# 22  용산동4가      2
# 23  용산동5가    209
# 24  원효로1가    418
# 25  원효로2가    145
# 26  원효로3가    156
# 27  원효로4가    241
# 28  청파동1가    458
# 29  청파동2가    137
# 30  청파동3가    179
# 31  한강로1가    276
# 32  한강로2가    592
# 33  한강로3가    614

# %%
종로구 = pd.read_csv('미니프로젝트_데이터/종로구.csv', encoding='cp949')
종로구 = 종로구[['법정동명', '등록동물수(마리)']]
종로구.columns = ['동명', '등록동물수']
종로구
# Out:
#        동명  등록동물수
# 0      계동     87
# 1      재동      7
# 2      평동     47
# 3      화동      9
# 4     가회동    112
# ..    ...    ...
# 76   종로4가      3
# 77   종로5가     11
# 78   종로6가     36
# 79  신문로1가      5
# 80  신문로2가     61
#
# [81 rows x 2 columns]

# %%
중구 = pd.read_csv('미니프로젝트_데이터/중구.csv', encoding='cp949')
중구['등록동물수'] = round(중구.동물소유자수 * 중구.동물소유자당동물등록수)
중구 = 중구[['읍면동(법정동)', '등록동물수']]
중구.columns = ['동명', '등록동물수']
중구
# Out:
#         동명  등록동물수
# 0       다동  131.0
# 1       정동   50.0
# 2       초동    5.0
# 3      남창동   32.0
# 4      무교동    2.0
# ..     ...    ...
# 59   회현동2가   89.0
# 60   회현동3가    4.0
# 61  남대문로5가   51.0
# 62   회현동3가    4.0
# 63  남대문로5가   51.0
#
# [64 rows x 2 columns]

# %%
중랑구 = pd.read_csv('미니프로젝트_데이터/중랑구.csv', encoding='cp949')
중랑구 = 중랑구[['읍면동(법정동)', '합계']]
중랑구.columns = ['동명', '등록동물수']
중랑구
# Out:
#     동명  등록동물수
# 0   묵동   3165
# 1  망우동   3027
# 2  면목동   9486
# 3  상봉동   2877
# 4  신내동   3255
# 5  중화동   3000

# %%
# 구별로 총계, 데이터프레임, 지도표현
total_df = pd.DataFrame(columns=['구', '등록동물수'])
구 = ['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
    '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
    '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구']

등록동물수 = [
  강남구.등록동물수.sum(), 강동구.등록동물수.sum(), 강북구.등록동물수.sum(), 강서구.등록동물수.sum(),
  관악구.등록동물수.sum(), 광진구.등록동물수.sum(), 구로구.등록동물수.sum(), 금천구.등록동물수.sum(),
  노원구.등록동물수.sum(), 도봉구.등록동물수.sum(), 동대문구.등록동물수.sum(), 동작구.등록동물수.sum(),
  마포구.등록동물수.sum(), 16944, 0, 성동구.등록동물수.sum(), 성북구.등록동물수.sum(),
  송파구.등록동물수.sum(), 0, 영등포구.등록동물수.sum(), 용산구.등록동물수.sum(), 0,
  종로구.등록동물수.sum(), 중구.등록동물수.sum(), 중랑구.등록동물수.sum()]

total_df['구'] = 구
total_df['등록동물수'] = 등록동물수
total_df
# Out:
#        구    등록동물수
# 0    강남구  31371.0
# 1    강동구  18281.0
# 2    강북구  15652.0
# 3    강서구  28055.0
# 4    관악구  25027.0
# 5    광진구  21034.0
# 6    구로구  22438.0
# 7    금천구  13552.0
# 8    노원구   1520.0
# 9    도봉구  14676.0
# 10  동대문구  19565.0
# 11   동작구  20295.0
# 12   마포구  24786.0
# 13  서대문구  16944.0
# 14   서초구      0.0
# 15   성동구  18671.0
# 16   성북구  21877.0
# 17   송파구  30488.0
# 18   양천구      0.0
# 19  영등포구  19964.0
# 20   용산구  19120.0
# 21   은평구      0.0
# 22   종로구  10418.0
# 23    중구   8393.0
# 24   중랑구  24810.0

# %%
# 막대 그래프

plt.figure(figsize=(15, 5))
plt.bar(total_df['구'], total_df['등록동물수'])
plt.title('서울시 구별 등록동물수', fontsize=20)

# 수치가 높은거랑 낮은거 색깔 다르게
# Out:
# Text(0.5, 1.0, '서울시 구별 등록동물수')

# %%
# 지도 시각화
import folium
import json

file = 'seoul_geo_simple.json'
data = open(file, 'r', encoding='utf-8').read()
geo_data = json.loads(data) 

m = folium.Map(location=[37.566345, 126.977893], zoom_start=11, tiles="OpenStreetMap")

folium.Choropleth(
    geo_data=geo_data,
    name='인구수',
    data=total_df,
    columns=('구', '등록동물수'),
    key_on='feature.properties.name',
    fill_color='BuPu',  # viridis
    legend_name='total',
    line_weight=2,
    highlight=True
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 서울시 구별 인구분포
file = '미니프로젝트_데이터/202403_202403_주민등록인구및세대현황_월간.csv'
df = pd.read_csv(file, encoding = 'cp949')

# 데이터 전처리
df_t = df[ ['행정구역','2024년03월_총인구수','2024년03월_남자 인구수','2024년03월_여자 인구수']]
df_t.columns = ['행정구역','total', '남자인구', '여자인구']
df_t.drop(0, axis=0, inplace=True)
df_t.insert(2, '시군구', df_t['행정구역'].str.split(' ').str[2])
df_t['total'] = df_t['total'].str.replace(',','').apply('int64')
df_t['남자인구'] = df_t['남자인구'].str.replace(',','').apply('int64')
df_t['여자인구'] = df_t['여자인구'].str.replace(',','').apply('int64')
df_t = df_t[['시군구', 'total']].sort_values('시군구')
df_t
# Out:
# /var/folders/9k/vdhwnv4n6zs1fzzz3xy8666h0000gn/T/ipykernel_15257/2958363350.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t.drop(0, axis=0, inplace=True)
# /var/folders/9k/vdhwnv4n6zs1fzzz3xy8666h0000gn/T/ipykernel_15257/2958363350.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t['total'] = df_t['total'].str.replace(',','').apply('int64')
# /var/folders/9k/vdhwnv4n6zs1fzzz3xy8666h0000gn/T/ipykernel_15257/2958363350.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
plt.figure(figsize=(15, 5))
plt.bar(df_t['시군구'], df_t['total'])
plt.title('서울시 구역별 인구분포', fontsize=20)
# Out:
# Text(0.5, 1.0, '서울시 구역별 인구분포')

# %%
file = 'seoul_geo_simple.json'
data = open(file, 'r', encoding='utf-8').read()
geo_data = json.loads(data)

m = folium.Map(location=[37.566345, 126.977893], zoom_start=11, tiles="OpenStreetMap")

folium.Choropleth(
    geo_data=geo_data,
    name='인구수',
    data=df_t,
    columns=('시군구', 'total'),
    key_on='feature.properties.name',
    fill_color='BuPu',  # viridis
    legend_name='total',
    line_weight=2,
    highlight=True
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
pct = pd.read_csv('미니프로젝트_데이터/유무퍼센트.csv')
pct.drop([0,1], axis=0, inplace=True)
pct.drop('구분별(1)', axis=1, inplace=True)
pct.columns = ['구', '유', '무']
pct = pct.sort_values('구')
pct['유'] = pct['유'].astype('float64')
pct['무'] = pct['무'].astype('float64')
pct
# Out:
#        구     유     무
# 24   강남구  44.1  55.9
# 26   강동구  25.6  74.4
# 10   강북구  21.1  78.9
# 17   강서구  17.1  82.9
# 22   관악구  22.3  77.7
# 6    광진구  21.4  78.6
# 18   구로구  17.3  82.7
# 19   금천구  13.5  86.5
# 12   노원구  28.4  71.6
# 11   도봉구  19.4  80.6
# 7   동대문구  19.7  80.3
# 21   동작구  21.2  78.8
# 15   마포구  23.6  76.4
# 14  서대문구  20.2  79.8
# 23   서초구  22.3  77.7
# 5    성동구  19.1  80.9
# 9    성북구  20.2  79.8
# 25   송파구  22.6  77.4
# 16   양천구  15.2  84.8
# 20  영등포구  18.4  81.6
# 4    용산구  17.1  82.9
# 13   은평구  18.1  81.9
# 2    종로구  33.9  66.1
# 3     중구  14.7  85.3
# 8    중랑구  30.1  69.9

# %%
plt.figure(figsize=(15,10))
pct.set_index('구').plot(kind='barh', stacked=True, color=['#C79FEF', '#E6E6FA'])
# Out:
# <Axes: ylabel='구'>

# %% [markdown]
# ## 정리
# - 데이터를 모아서 하나의 형식으로 만들고 필요한 부분만 뽑아내는 전처리 과정이 오래걸림
# - (열 이름변경, 널값제거, 데이터 형식 변환)
# - 반려동물 등록수가 가장 많은 구는 송파구, 송파구에 인구수도 제일 많다
# - 대체적으로 인구수가 높은곳이 반려동물 등록수도 많은편
# - 강남구는 인구수대비 반려등물 등록 비율이 높은편이라 강남구가 두번째로 반려동물등록수가 높음
#
# - 추가해볼 내용 : 각 구별 인프라(미용, 병원, 산책로 등) 현황에 대해서 연관성이 있는지
