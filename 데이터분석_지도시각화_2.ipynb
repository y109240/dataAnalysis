# %% [markdown]
# # 한글폰트 설정 및 라이브러리 임포트

# %%
# 코드 실행 후 재시작
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %% [markdown]
# # 필요한 라이브러리 import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import warnings

# %%
# 맥os 주피터에서 한글설정
from matplotlib import rc
rc('font', family='AppleGothic')

# %%
# 맥os colab에서 한글설정
fe = fm.FontEntry(fname='r/usr/share/fonts/truetype/nanum/NanumGothic.ttf', name="NanumGothic")
fm.fontManager.ttflist.insert(0, fe)
plt.rcParams.update({'font.size':13, 'font.family':'NanumGothic'})

# %%
# 멧플롯립 한글폰트 지정
plt.rc('font', family='NanumBarunGothic')    # 코랩에서 사용
plt.rc('font', family='Malgun Gothic')    # 윈도우에서 사용
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# # 빵덕후들의 지도
#  - 제주도 서귀포시의 제과점 위치 정보를 제공하는 지도 시각화

# %% [markdown]
# ## 파일 읽어서 데이터프레임 생성하기

# %%
import pandas as pd
df = pd.read_csv('geo_data/제주특별자치도_서귀포시_제과점현황_20240401.csv', encoding='cp949')

# %% [markdown]
# ## 데이터 구조 탐색하기

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   업종명       167 non-null    object
#  1   업소명       167 non-null    object
#  2   소재지(도로명)  165 non-null    object
#  3   소재지(지번)   167 non-null    object
#  4   위도        167 non-null    float64
#  5   경도        167 non-null    float64
#  6   데이터기준일자   167 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 9.3+ KB

# %%
# '업종명'컬럼의 데이터 확인하기
df['업종명'].value_counts()
# Out:
# 업종명
# 제과점영업    167
# Name: count, dtype: int64

# %%
# 결측치 데이터 확인하기
# df.isnull()
df.isnull().sum()
# Out:
# 업종명         0
# 업소명         0
# 소재지(도로명)    2
# 소재지(지번)     0
# 위도          0
# 경도          0
# 데이터기준일자     0
# dtype: int64

# %%
# 특정 컬럼의 결측치 확인
df[df['소재지(도로명)'].isnull()]
# df.loc[df['소재지(도로명)'].isnull()]
# Out:
#        업종명     업소명 소재지(도로명)                      소재지(지번)         위도  \
# 144  제과점영업    빵하우스      NaN      제주특별자치도 서귀포시 동홍동 645-3   33.252836
# 159  제과점영업  빙그레제과점      NaN  제주특별자치도 서귀포시 대정읍 하모리 824번지   33.221995
#
#              경도     데이터기준일자
# 144  126.570179  2024-04-01
# 159  126.254367  2024-04-01

# %% [markdown]
# ## 데이터 전처리하기

# %% [markdown]
# ### 이상치 확인하기
# - 수치형 값을 갖는 '위도','경도' 컬럼에 이상치가 있는지 boxplot으로 확인

# %%
import matplotlib.pyplot as plt

ax1 = plt.subplot(121) # (1) 첫번째 공간에 axes생성
ax1.boxplot(df['위도'])
ax2 = plt.subplot(122)
ax2.boxplot(df['경도'])
plt.show()

# %% [markdown]
# ### 불필요한 컬럼 삭제하기
# - '소재지(도로명)' 컬럼 대신 '소재지(지번)'을 사용하면 되기 때문에 이 컬럼은 삭제한다
# - '업종명', '데이터기준일자' 컬럼도 분석에 필요하지 않은 내용으로 보고 삭제한다.

# %%
df.drop(columns=['업종명', '소재지(도로명)', '데이터기준일자'], axis=1, inplace=True)
df.isnull().sum()
# Out:
# 업소명        0
# 소재지(지번)    0
# 위도         0
# 경도         0
# dtype: int64

# %%
df.head()
# Out:
#                            업소명                      소재지(지번)         위도  \
# 0           노베케이션(No Vacation)   제주특별자치도 서귀포시 표선면 표선리 40-3   33.325364
# 1            그랜드파파(Grand papa)      제주특별자치도 서귀포시 서귀동 829-5   33.246848
# 2               위드윗(withwheat)      제주특별자치도 서귀포시 서홍동 166-5   33.267520
# 3                         허니제과  제주특별자치도 서귀포시 대정읍 구억리 365-5   33.280342
# 4  도트베이글팩토리(DOT BAGEL FACTORY)      제주특별자치도 서귀포시 서호동 325-1   33.255598
#
#            경도
# 0  126.837714
# 1  126.560673
# 2  126.558177
# 3  126.301778
# 4  126.526362

# %% [markdown]
# ### 소재지(지번) 주소에서 읍,면,동 정보 추출하기

# %%
df['소재지(지번)'].str.split(' ').str[2]
# Out:
# 0      표선면
# 1      서귀동
# 2      서홍동
# 3      대정읍
# 4      서호동
#       ...
# 162    서귀동
# 163    서귀동
# 164    남원읍
# 165    대정읍
# 166    안덕면
# Name: 소재지(지번), Length: 167, dtype: object

# %%
df['읍면동'] = df['소재지(지번)'].str.split(' ').str[2]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   업소명      167 non-null    object
#  1   소재지(지번)  167 non-null    object
#  2   위도       167 non-null    float64
#  3   경도       167 non-null    float64
#  4   읍면동      167 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 6.7+ KB

# %% [markdown]
# ## 데이터 탐색하기

# %% [markdown]
# ### 빵집이 제일 많은 동네는 어디일까?

# %%
df['읍면동'].value_counts()
# Out:
# 읍면동
# 대정읍    26
# 안덕면    23
# 성산읍    16
# 동홍동    13
# 서귀동    12
# 남원읍    10
# 표선면    10
# 하효동     9
# 중문동     9
# 서호동     8
# 법환동     6
# 서홍동     6
# 강정동     6
# 색달동     5
# 회수동     2
# 토평동     2
# 상예동     1
# 신효동     1
# 월평동     1
# 호근동     1
# Name: count, dtype: int64

# %%
# 대정읍-> 안덕면 -> 성산읍 순서로 빵집이 많다.

# %%
df.loc[df['읍면동'] == '대정읍'][['업소명', '소재지(지번)']]
# Out:
#                          업소명                              소재지(지번)
# 3                       허니제과          제주특별자치도 서귀포시 대정읍 구억리 365-5
# 5              수께로(Suekkero)          제주특별자치도 서귀포시 대정읍 하모리 923-5
# 8                     소낭베이커리            제주특별자치도 서귀포시 대정읍 상모리 418
# 9                       우리제과         제주특별자치도 서귀포시 대정읍 하모리 1497-4
# 19                   제주우도슈크레    제주특별자치도 서귀포시 대정읍 보성리 2547 빌리지 더휴
# 20   베이커리픽키키(Bakery Pickiki)         제주특별자치도 서귀포시 대정읍 상모리 3854-8
# 32    버터리팬트리(BUTTERY PANTRY)         제주특별자치도 서귀포시 대정읍 하모리 1560-3
# 44         아베크아롬(AVEC AROME)            제주특별자치도 서귀포시 대정읍 구억리 980
# 55                       라퐁텐          제주특별자치도 서귀포시 대정읍 보성리 163-5
# 58                        스텔         제주특별자치도 서귀포시 대정읍 일과리 1933번지
# 68                 수애기베이커리카페        제주특별자치도 서귀포시 대정읍 동일리 3132 1층
# 76                      미쁜제과      제주특별자치도 서귀포시 대정읍 신도리 2349-13번지
# 77   베이크샵스니프(BAKESHOP SNIFF)   제주특별자치도 서귀포시 대정읍 구억리 1115 해동그린앤골드
# 84                       달콤해      제주특별자치도 서귀포시 대정읍 상모리 3938번지 1층
# 86               뚜레쥬르제주영어도시점         제주특별자치도 서귀포시 대정읍 보성리 2417번지
# 91               파리바게뜨대정하나로점  제주특별자치도 서귀포시 대정읍 상모리 3453번지 , 지하1층
# 104               뚜레쥬르제주모슬포점         제주특별자치도 서귀포시 대정읍 하모리 1293번지
# 109             파리바게트제주영어도시점         제주특별자치도 서귀포시 대정읍 보성리 2372-4
# 124                    황금륭버거             제주특별자치도 서귀포시 대정읍 신도리 10
# 125                 황금륭스마일버거        제주특별자치도 서귀포시 대정읍 신도리 11 외1필지
# 133                 파리바게뜨대정점       제주특별자치도 서귀포시 대정읍 하모리 820-16번지
# 138                   중앙베이커리       제주특별자치도 서귀포시 대정읍 하모리 2143-3번지
# 157                    신세계제과         제주특별자치도 서귀포시 대정읍 하모리 849-21
# 158                      온누리          제주특별자치도 서귀포시 대정읍 하모리 852-4
# 159                   빙그레제과점          제주특별자치도 서귀포시 대정읍 하모리 824번지
# 165   버터리팬트리(BUTTERY PANTRY)         제주특별자치도 서귀포시 대정읍 하모리 1560-3

# %% [markdown]
# ### 중문동/서호동에 있는 빵집의 주소 알아보기

# %%
# df.loc[df['읍면동'] == '대정읍'][['업소명', '소재지(지번)']]
df.loc[df['읍명동'] == '서호동'][['업소명', '소재지(지번)']]

# %% [markdown]
# ## 데이터 시각화 하기
# - 지도위에 위치와 정보 표시하기
# - folium 사용법 <br>
# https://python-visualization.github.io/folium/quickstart.html#Getting-Started

# %% [markdown]
# ### folium사용하기

# %%
# !pip install folium

# %%
import folium

# %%
folium.__version__
# Out:
# '0.16.0'

# %%
# 초기위치(위도,경도) = 서귀포시
lati, long = 33.2541205, 126.560076
map = folium.Map(location= [lati, long], zoom_start=10)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1f73e7e8f1ad587946899b194f5bac7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1f73e7e8f1ad587946899b194f5bac7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1f73e7e8f1ad587946899b194f5bac7 = L.map(
#                 &quot;map_f1f73e7e8f1ad587946899b194f5bac7&quot;,
#                 {
#                     center: [33.2541205, 126.560076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2de876b6f529d28e9cc12715af01abd1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2de876b6f529d28e9cc12715af01abd1.addTo(map_f1f73e7e8f1ad587946899b194f5bac7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map = folium.Map(location=[lati, long], zoom_start=10)
tooltip = 'click'
folium.Marker(location=[lati, long],
              popup='<strong>hello jeju</strong>',
              icon=folium.Icon(color='pink', icon='heart'),
              tooltip=tooltip
).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b42377013d241b0caa20f2ecdbccda22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b42377013d241b0caa20f2ecdbccda22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b42377013d241b0caa20f2ecdbccda22 = L.map(
#                 &quot;map_b42377013d241b0caa20f2ecdbccda22&quot;,
#                 {
#                     center: [33.2541205, 126.560076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cf0bbcb11df223ab72ca05c16893d51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0cf0bbcb11df223ab72ca05c16893d51.addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#             var marker_deb9598bbd1efbbf4bffd572641af511 = L.marker(
#                 [33.2541205, 126.560076],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#             var icon_561ce4348233192573e225b322cd7389 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_deb9598bbd1efbbf4bffd572641af511.setIcon(icon_561ce4348233192573e225b322cd7389);
#
#
#         var popup_9a8ab69747a3a7c6e340f303efedfb12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12b8e4d201cc6545096a93107254bfaa = $(`&lt;div id=&quot;html_12b8e4d201cc6545096a93107254bfaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello jeju&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_9a8ab69747a3a7c6e340f303efedfb12.setContent(html_12b8e4d201cc6545096a93107254bfaa);
#
#
#
#         marker_deb9598bbd1efbbf4bffd572641af511.bindPopup(popup_9a8ab69747a3a7c6e340f303efedfb12)
#         ;
#
#
#
#
#             marker_deb9598bbd1efbbf4bffd572641af511.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 제과점 위치 마커 표시하기

# %%
df.head()
# Out:
#            업소명                           소재지(지번)         위도          경도  읍면동
# 40        구우쿠다           제주특별자치도 서귀포시 강정동 143-5   33.257165  126.507996  강정동
# 43     미베이커리카페             제주특별자치도 서귀포시 강정동 847   33.236002  126.498828  강정동
# 102      봉주르마담         제주특별자치도 서귀포시 강정동 208-4번지   33.252772  126.503327  강정동
# 103  주식회사시스터필드  제주특별자치도 서귀포시 강정동 231-2 1층 103-2호  33.248997  126.507319  강정동
# 37        크라상점          제주특별자치도 서귀포시 강정동 207-13   33.253063  126.503547  강정동

# %%
for idx in df.index:
    lat = df.loc[idx,'위도']
    lng = df.loc[idx,'경도']
    marker = folium.Marker(
        location = [lat, lng],
        popup = f"{df.loc[idx, '업소명']}"
    )
    marker.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b42377013d241b0caa20f2ecdbccda22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b42377013d241b0caa20f2ecdbccda22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b42377013d241b0caa20f2ecdbccda22 = L.map(
#                 &quot;map_b42377013d241b0caa20f2ecdbccda22&quot;,
#                 {
#                     center: [33.2541205, 126.560076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cf0bbcb11df223ab72ca05c16893d51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0cf0bbcb11df223ab72ca05c16893d51.addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#             var marker_deb9598bbd1efbbf4bffd572641af511 = L.marker(
#                 [33.2541205, 126.560076],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#             var icon_561ce4348233192573e225b322cd7389 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_deb9598bbd1efbbf4bffd572641af511.setIcon(icon_561ce4348233192573e225b322cd7389);
#
#
#         var popup_9a8ab69747a3a7c6e340f303efedfb12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12b8e4d201cc6545096a93107254bfaa = $(`&lt;div id=&quot;html_12b8e4d201cc6545096a93107254bfaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello jeju&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_9a8ab69747a3a7c6e340f303efedfb12.setContent(html_12b8e4d201cc6545096a93107254bfaa);
#
#
#
#         marker_deb9598bbd1efbbf4bffd572641af511.bindPopup(popup_9a8ab69747a3a7c6e340f303efedfb12)
#         ;
#
#
#
#
#             marker_deb9598bbd1efbbf4bffd572641af511.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_0cf0bbcb11df223ab72ca05c16893d51.addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#             var marker_db327fe537494deae5e9cbac79356989 = L.marker(
#                 [33.32536384, 126.8377136],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#         var popup_ce5b4bc7e68ffc621423babebb6338b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5827ff3eed3edd851a949fc33860f443 = $(`&lt;div id=&quot;html_5827ff3eed3edd851a949fc33860f443&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;업소명                노베케이션(No Vacation) 소재지(지번)    제주특별자치도 서귀포시 표선면 표선리 40-3  위도                          33.325364 경도                         126.837714 읍면동                               표선면 Name: 0, dtype: object&lt;/div&gt;`)[0];
#                 popup_ce5b4bc7e68ffc621423babebb6338b5.setContent(html_5827ff3eed3edd851a949fc33860f443);
#
#
#
#         marker_db327fe537494deae5e9cbac79356989.bindPopup(popup_ce5b4bc7e68ffc621423babebb6338b5)
#         ;
#
#
#
#
#             var marker_7929fa1e28dcd6675691b2c2e509215c = L.marker(
#                 [33.24684824, 126.5606733],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#         var popup_1079593101659b2827f972952315b2d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d2fe5f21af8c6e12abf137674e1d63d = $(`&lt;div id=&quot;html_7d2fe5f21af8c6e12abf137674e1d63d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;업소명              그랜드파파(Grand papa) 소재지(지번)    제주특별자치도 서귀포시 서귀동 829-5  위도                       33.246848 경도                      126.560673 읍면동                            서귀동 Name: 1, dtype: object&lt;/div&gt;`)[0];
#                 popup_1079593101659b2827f972952315b2d8.setContent(html_7d2fe5f21af8c6e12abf137674e1d63d);
#
#
#
#         marker_7929fa1e28dcd6675691b2c2e509215c.bindPopup(popup_1079593101659b2827f972952315b2d8)
#         ;
#
#
#
#
#             var marker_bd4a1245f1f65ece59ce49bf561ee196 = L.marker(
#                 [33.26752037, 126.5581773],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#         var popup_e21944f6e501f48d18857cd890a674f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91a56701b33b0cf711a44c580c823a4c = $(`&lt;div id=&quot;html_91a56701b33b0cf711a44c580c823a4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;업소명                 위드윗(withwheat) 소재지(지번)    제주특별자치도 서귀포시 서홍동 166-

# %% [markdown]
# ### 마커에 정보 넣기

# %%
for idx in df.index:
    lat = df.loc[idx,'위도']
    lng = df.loc[idx,'경도']
    marker = folium.Marker(
        location = [lat, lng],
        popup = f"<div style='width:100px'> <strong>{df.loc[idx,'업소명']}</strong><br>\
            {df.loc[idx,'소재지(지번)']}</div>",
            icon = folium.Icon(color='orange', icon='cloud')
    )
    marker.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b42377013d241b0caa20f2ecdbccda22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b42377013d241b0caa20f2ecdbccda22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b42377013d241b0caa20f2ecdbccda22 = L.map(
#                 &quot;map_b42377013d241b0caa20f2ecdbccda22&quot;,
#                 {
#                     center: [33.2541205, 126.560076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cf0bbcb11df223ab72ca05c16893d51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0cf0bbcb11df223ab72ca05c16893d51.addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#             var marker_deb9598bbd1efbbf4bffd572641af511 = L.marker(
#                 [33.2541205, 126.560076],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#             var icon_561ce4348233192573e225b322cd7389 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_deb9598bbd1efbbf4bffd572641af511.setIcon(icon_561ce4348233192573e225b322cd7389);
#
#
#         var popup_9a8ab69747a3a7c6e340f303efedfb12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12b8e4d201cc6545096a93107254bfaa = $(`&lt;div id=&quot;html_12b8e4d201cc6545096a93107254bfaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello jeju&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_9a8ab69747a3a7c6e340f303efedfb12.setContent(html_12b8e4d201cc6545096a93107254bfaa);
#
#
#
#         marker_deb9598bbd1efbbf4bffd572641af511.bindPopup(popup_9a8ab69747a3a7c6e340f303efedfb12)
#         ;
#
#
#
#
#             marker_deb9598bbd1efbbf4bffd572641af511.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_0cf0bbcb11df223ab72ca05c16893d51.addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#             var marker_db327fe537494deae5e9cbac79356989 = L.marker(
#                 [33.32536384, 126.8377136],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#         var popup_ce5b4bc7e68ffc621423babebb6338b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5827ff3eed3edd851a949fc33860f443 = $(`&lt;div id=&quot;html_5827ff3eed3edd851a949fc33860f443&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;업소명                노베케이션(No Vacation) 소재지(지번)    제주특별자치도 서귀포시 표선면 표선리 40-3  위도                          33.325364 경도                         126.837714 읍면동                               표선면 Name: 0, dtype: object&lt;/div&gt;`)[0];
#                 popup_ce5b4bc7e68ffc621423babebb6338b5.setContent(html_5827ff3eed3edd851a949fc33860f443);
#
#
#
#         marker_db327fe537494deae5e9cbac79356989.bindPopup(popup_ce5b4bc7e68ffc621423babebb6338b5)
#         ;
#
#
#
#
#             var marker_7929fa1e28dcd6675691b2c2e509215c = L.marker(
#                 [33.24684824, 126.5606733],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#         var popup_1079593101659b2827f972952315b2d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d2fe5f21af8c6e12abf137674e1d63d = $(`&lt;div id=&quot;html_7d2fe5f21af8c6e12abf137674e1d63d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;업소명              그랜드파파(Grand papa) 소재지(지번)    제주특별자치도 서귀포시 서귀동 829-5  위도                       33.246848 경도                      126.560673 읍면동                            서귀동 Name: 1, dtype: object&lt;/div&gt;`)[0];
#                 popup_1079593101659b2827f972952315b2d8.setContent(html_7d2fe5f21af8c6e12abf137674e1d63d);
#
#
#
#         marker_7929fa1e28dcd6675691b2c2e509215c.bindPopup(popup_1079593101659b2827f972952315b2d8)
#         ;
#
#
#
#
#             var marker_bd4a1245f1f65ece59ce49bf561ee196 = L.marker(
#                 [33.26752037, 126.5581773],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#         var popup_e21944f6e501f48d18857cd890a674f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91a56701b33b0cf711a44c580c823a4c = $(`&lt;div id=&quot;html_91a56701b33b0cf711a44c580c823a4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;업소명                 위드윗(withwheat) 소재지(지번)    제주특별자치도 서귀포시 서홍동 166-

# %%
# 데이터 정렬
df = df.sort_values(by=['읍면동','업소명'], ascending=True)

# 읍면동별로 아이콘 컬러를 다르게 설정하기
# help(folium.icon)
colors = ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray']
v_idx = 0
v_color = 'orange'
v_읍면동 = df.loc[v_idx, '읍면동']
for idx in df.index:
    # 아이콘 색상 다르게 지정(읍면동별로)
    if df.loc[idx, '읍면동'] == v_읍면동:
        v_color = colors[v_idx]
    else:
        if len(colors) -1 == v_idx:
            v_idx = 0
        else:
            v_idx += 1
        v_color = colors[v_idx]
        v_읍면동 = df.loc[idx, '읍면동']
    
    lat = df.loc[idx,'위도']
    lng = df.loc[idx,'경도']
    marker = folium.Marker(
        location = [lat, lng],
        popup = f"<div style='width:100px'><strong>{df.loc[idx,'업소명']}</strong><br>\
            {df.loc[idx, '소재지(지번)']}</div>",
        icon = folium.Icon(color=v_color, icon='cloud')
    )
    marker.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b42377013d241b0caa20f2ecdbccda22 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b42377013d241b0caa20f2ecdbccda22&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b42377013d241b0caa20f2ecdbccda22 = L.map(
#                 &quot;map_b42377013d241b0caa20f2ecdbccda22&quot;,
#                 {
#                     center: [33.2541205, 126.560076],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cf0bbcb11df223ab72ca05c16893d51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0cf0bbcb11df223ab72ca05c16893d51.addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#             var marker_deb9598bbd1efbbf4bffd572641af511 = L.marker(
#                 [33.2541205, 126.560076],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#             var icon_561ce4348233192573e225b322cd7389 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_deb9598bbd1efbbf4bffd572641af511.setIcon(icon_561ce4348233192573e225b322cd7389);
#
#
#         var popup_9a8ab69747a3a7c6e340f303efedfb12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12b8e4d201cc6545096a93107254bfaa = $(`&lt;div id=&quot;html_12b8e4d201cc6545096a93107254bfaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;hello jeju&lt;/strong&gt;&lt;/div&gt;`)[0];
#                 popup_9a8ab69747a3a7c6e340f303efedfb12.setContent(html_12b8e4d201cc6545096a93107254bfaa);
#
#
#
#         marker_deb9598bbd1efbbf4bffd572641af511.bindPopup(popup_9a8ab69747a3a7c6e340f303efedfb12)
#         ;
#
#
#
#
#             marker_deb9598bbd1efbbf4bffd572641af511.bindTooltip(
#                 `&lt;div&gt;
#                      click
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_0cf0bbcb11df223ab72ca05c16893d51.addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#             var marker_db327fe537494deae5e9cbac79356989 = L.marker(
#                 [33.32536384, 126.8377136],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#         var popup_ce5b4bc7e68ffc621423babebb6338b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5827ff3eed3edd851a949fc33860f443 = $(`&lt;div id=&quot;html_5827ff3eed3edd851a949fc33860f443&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;업소명                노베케이션(No Vacation) 소재지(지번)    제주특별자치도 서귀포시 표선면 표선리 40-3  위도                          33.325364 경도                         126.837714 읍면동                               표선면 Name: 0, dtype: object&lt;/div&gt;`)[0];
#                 popup_ce5b4bc7e68ffc621423babebb6338b5.setContent(html_5827ff3eed3edd851a949fc33860f443);
#
#
#
#         marker_db327fe537494deae5e9cbac79356989.bindPopup(popup_ce5b4bc7e68ffc621423babebb6338b5)
#         ;
#
#
#
#
#             var marker_7929fa1e28dcd6675691b2c2e509215c = L.marker(
#                 [33.24684824, 126.5606733],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#         var popup_1079593101659b2827f972952315b2d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7d2fe5f21af8c6e12abf137674e1d63d = $(`&lt;div id=&quot;html_7d2fe5f21af8c6e12abf137674e1d63d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;업소명              그랜드파파(Grand papa) 소재지(지번)    제주특별자치도 서귀포시 서귀동 829-5  위도                       33.246848 경도                      126.560673 읍면동                            서귀동 Name: 1, dtype: object&lt;/div&gt;`)[0];
#                 popup_1079593101659b2827f972952315b2d8.setContent(html_7d2fe5f21af8c6e12abf137674e1d63d);
#
#
#
#         marker_7929fa1e28dcd6675691b2c2e509215c.bindPopup(popup_1079593101659b2827f972952315b2d8)
#         ;
#
#
#
#
#             var marker_bd4a1245f1f65ece59ce49bf561ee196 = L.marker(
#                 [33.26752037, 126.5581773],
#                 {}
#             ).addTo(map_b42377013d241b0caa20f2ecdbccda22);
#
#
#         var popup_e21944f6e501f48d18857cd890a674f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91a56701b33b0cf711a44c580c823a4c = $(`&lt;div id=&quot;html_91a56701b33b0cf711a44c580c823a4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;업소명                 위드윗(withwheat) 소재지(지번)    제주특별자치도 서귀포시 서홍동 166-
