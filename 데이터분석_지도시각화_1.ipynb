# %% [markdown]
# # 데이터 분석
#
# ## 6. 지도를 이용한 데이터 시각화
# **(단, 지도에서 웹브라우저를 실행할 경우 VSC에서 실행)**

# %% [markdown]
# ----------------------------------

# %% [markdown]
# ## 01.지도에 표시하기

# %% [markdown]
# ### #folium 라이브러리 소개
# * 파이썬에서 인터랙티브한 Leaflet 지도를 생성하는 데 사용되는 라이브러리
# * Leaflet은 인터랙티브한 웹 지도를 만들기 위한 오픈 소스 자바스크립트 라이브러리임
# * Leaflet을 사용하면 사용자가 지도를 확대, 축소하고 이동할 수 있는 등 다양한 상호 작용 기능을 제공할 수 있음
# * Folium을 사용하면 Leaflet JavaScript 라이브러리의 기능을 파이썬 환경에서 활용할 수 있으며, 데이터 시각화 및 지리 정보 시스템(GIS) 작업에 적합
# * **Folium의 주요 특징**
#     - 인터랙티브 지도 생성: 사용자가 지도를 확대/축소, 마커, 팝업 가능
#     - 다양한 타일 제공: OpenStreetMap, Mapbox, Stamen 등
#     - 지리 공간 데이터 시각화: GeoJSON 형식의 데이터를 지도 위에 표시하고 스타일링할 수 있음
#     - 마커 클러스터링: 지도에 많은 수의 마커를 효율적으로 관리할 수 있음

# %% [markdown]
# ### #라이브러리 설치하기
# - https://python-visualization.github.io/folium/latest/
# -

# %%
# !pip install folium # --upgrade

# %% [markdown]
# ### #라이브러리 설치 확인하기
# 아래 코드를 실행한 후 오류 메시지가 없으면 성공적으로 설치된 것입니다.

# %%
import folium 

folium.__version__
# Out:
# '0.16.0'

# %% [markdown]
# ### [실습] :  지도에 숭례문 위치 표시하기 : folium.Map()
# 구글지도에서 찾은 숭례문의 위도 & 경도 값을 가지고 folium 지도에 마커로 표시를 해보세요.

# %% [markdown]
# - **구글맵**에서 **숭례문**의 위도/경도 좌표값 기록해 두기
# - https://www.google.com/maps ~~
# - !3d37.559984!4d126.9753071 --> **위도:37.559984** & **경도:126.9753071**

# %%
import folium

# 지도 중심좌표 지정하기
center = [37.559984, 126.9753071] # 숭례문 위도와 경도

# 지도 객체 만들기
folium.Map(location=center, zoom_start=16)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87ee87757148395bf319371e8c5016cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87ee87757148395bf319371e8c5016cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_87ee87757148395bf319371e8c5016cf = L.map(
#                 &quot;map_87ee87757148395bf319371e8c5016cf&quot;,
#                 {
#                     center: [37.559984, 126.9753071],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2acce7a476769b8a05c1813617dacea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c2acce7a476769b8a05c1813617dacea.addTo(map_87ee87757148395bf319371e8c5016cf);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### #지도 종류 변경하기
# Map의 tiles 옵션값을 수정하여 folium 지도의 종류 변경 가능. (주의!: 과거 무료로 사용했던 지도 종류가 제한되어 지금은 사용할 수 없는 것이 많아짐.)
# * **지도 종류 변경 방법** :  folium.Map(tiles='CartoDB Positron') **tiles 옵션을 사용한다.**
# * **지도 종류** :
#      - "OpenStreetMap"(기본테마)
#      - "CartoDB Positron"
#      - "OpenRailwayMap" 등
#      - https://xyzservices.readthedocs.io/en/latest/gallery.html# 에서 참고

# %%
# 지도 종류 확인
help(folium.Map)
# Out:
# Help on class Map in module folium.folium:
#
# class Map(folium.elements.JSCSSMixin, branca.element.MacroElement)
#  |  Map(location: Optional[Sequence[float]] = None, width: Union[str, float] = '100%', height: Union[str, float] = '100%', left: Union[str, float] = '0%', top: Union[str, float] = '0%', position: str = 'relative', tiles: Union[str, folium.raster_layers.TileLayer, NoneType] = 'OpenStreetMap', attr: Optional[str] = None, min_zoom: int = 0, max_zoom: int = 18, zoom_start: int = 10, min_lat: int = -90, max_lat: int = 90, min_lon: int = -180, max_lon: int = 180, max_bounds: bool = False, crs: str = 'EPSG3857', control_scale: bool = False, prefer_canvas: bool = False, no_touch: bool = False, disable_3d: bool = False, png_enabled: bool = False, zoom_control: bool = True, font_size: str = '1rem', **kwargs: Union[str, float, bool, Sequence, dict, NoneType])
#  |
#  |  Create a Map with Folium and Leaflet.js
#  |
#  |  Generate a base map of given width and height with either default
#  |  tilesets or a custom tileset URL. Folium has built-in all tilesets
#  |  available in the ``xyzservices`` package. For example, you can pass
#  |  any of the following to the "tiles" keyword:
#  |
#  |      - "OpenStreetMap"
#  |      - "CartoDB Positron"
#  |      - "CartoDB Voyager"
#  |      - "NASAGIBS Blue Marble"
#  |
#  |  You can pass a custom tileset to Folium by passing a
#  |  :class:`xyzservices.TileProvider` or a Leaflet-style
#  |  URL to the tiles parameter: ``http://{s}.yourtiles.com/{z}/{x}/{y}.png``.
#  |
#  |  You can find a list of free tile providers here:
#  |  ``http://leaflet-extras.github.io/leaflet-providers/preview/``.
#  |  Be sure to check their terms and conditions and to provide attribution
#  |  with the `attr` keyword.
#  |
#  |  Parameters
#  |  ----------
#  |  location: tuple or list, default None
#  |      Latitude and Longitude of Map (Northing, Easting).
#  |  width: pixel int or percentage string (default: '100%')
#  |      Width of the map.
#  |  height: pixel int or percentage string (default: '100%')
#  |      Height of the map.
#  |  tiles: str or TileLayer or :class:`xyzservices.TileProvider`, default 'OpenStreetMap'
#  |      Map tileset to use. Can choose from a list of built-in tiles,
#  |      pass a :class:`xyzservices.TileProvider`,
#  |      pass a custom URL, pass a TileLayer object,
#  |      or pass `None` to create a map without tiles.
#  |      For more advanced tile layer options, use the `TileLayer` class.
#  |  min_zoom: int, default 0
#  |      Minimum allowed zoom level for the tile layer that is created.
#  |  max_zoom: int, default 18
#  |      Maximum allowed zoom level for the tile layer that is created.
#  |  zoom_start: int, default 10
#  |      Initial zoom level for the map.
#  |  attr: string, default None
#  |      Map tile attribution; only required if passing custom tile URL.
#  |  crs : str, default 'EPSG3857'
#  |      Defines coordinate reference systems for projecting geographical points
#  |      into pixel (screen) coordinates and back.
#  |      You can use Leaflet's values :
#  |      * EPSG3857 : The most common CRS for online maps, used by almost all
#  |      free and commercial tile providers. Uses Spherical Mercator projection.
#  |      Set in by default in Map's crs option.
#  |      * EPSG4326 : A common CRS among GIS enthusiasts.
#  |      Uses simple Equirectangular projection.
#  |      * EPSG3395 : Rarely used by some commercial tile providers.
#  |      Uses Elliptical Mercator projection.
#  |      * Simple : A simple CRS that maps longitude and latitude into
#  |      x and y directly. May be used for maps of flat surfaces
#  |      (e.g. game maps). Note that the y axis should still be inverted
#  |      (going from bottom to top).
#  |  control_scale : bool, default False
#  |      Whether to add a control scale on the map.
#  |  prefer_canvas : bool, default False
#  |      Forces Leaflet to use the Canvas back-end (if available) for
#  |      vector layers instead of SVG. This can increase performance
#  |      considerably in some cases (e.g. many thousands of circle
#  |      markers on the map).
#  |  no_touch : bool, default False
#  |      Forces Leaflet to not use touch events even if it detects them.
#  |  disable_3d : bool, default False
#  |      Forces Leaflet to not use hardware-accelerated CSS 3D
#  |      transforms for positioning (which may cause glitches in some
#  |      rare environments) even if they're supported.
#  |  zoom_control : bool, default True
#  |      Display zoom controls on the map.
#  |  font_size : int or float or string (default: '1rem')
#  |      The font size to use for Leaflet, can either be a number or a
#  |      string ending in 'rem', 'em', or 'px'.
#  |  **kwargs
#  |      Additional keyword arguments are passed to Leaflets Map class:
#  |      https://leafletjs.com/reference.html#map
#  |
#  |  Returns
#  |  -------
#  |  Folium Map Object
#  |
#  |  Examples
#  |  --------
#  |  >>> m = folium.Map(location=[45.523, -122.675], width=750, height=500)
#  |  >>> m = folium.Map(location=[45.523, -122.675], tiles="cartodb positron")
#  |  >>> m = folium.Map(
#  |  ...     location=[45.523, -122.675],
#  |  ...     zoom_start=2,
#  |  ...     tiles="https://api.mapbox.com/v4/mapbox.streets/{z}/{x}/{y}.png?access_token=mytoken",
#  |  ...     attr="Mapbox attribution",
#  |  ... )
#  |
#  |  Method resolution order:
#  |      Map
#  |      folium.elements.JSCSSMixin
#  |      branca.element.MacroElement
#  |      branca.element.Element
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, location: Optional[Sequence[float]] = None, width: Union[str, float] = '100%', height: Union[str, float] = '100%', left: Union[str, float] = '0%', top: Union[str, float] = '0%', position: str = 'relative', tiles: Union[str, folium.raster_layers.TileLayer, NoneType] = 'OpenStreetMap', attr: Optional[str] = None, min_zoom: int = 0, max_zoom: int = 18, zoom_start: int = 10, min_lat: int = -90, max_lat: int = 90, min_lon: int = -180, max_lon: int = 180, max_bounds: bool = False, crs: str = 'EPSG3857', control_scale: bool = False, prefer_canvas: bool = False, no_touch: bool = False, disable_3d: bool = False, png_enabled: bool = False, zoom_control: bool = True, font_size: str = '1rem', **kwargs: Union[str, float, bool, Sequence, dict, NoneType])
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  fit_bounds(self, bounds: Sequence[Sequence[float]], padding_top_left: Optional[Sequence[float]] = None, padding_bottom_right: Optional[Sequence[float]] = None, padding: Optional[Sequence[float]] = None, max_zoom: Optional[int] = None) -> None
#  |      Fit the map to contain a bounding box with the
#  |      maximum zoom level possible.
#  |
#  |      Parameters
#  |      ----------
#  |      bounds: list of (latitude, longitude) points
#  |          Bounding box specified as two points [southwest, northeast]
#  |      padding_top_left: (x, y) point, default None
#  |          Padding in the top left corner. Useful if some elements in
#  |          the corner, such as controls, might obscure objects you're zooming
#  |          to.
#  |      padding_bottom_right: (x, y) point, default None
#  |          Padding in the bottom right corner.
#  |      padding: (x, y) point, default None
#  |          Equivalent to setting both top left and bottom right padding to
#  |          the same value.
#  |      max_zoom: int, default None
#  |          Maximum zoom to be used.
#  |
#  |      Examples
#  |      --------
#  |      >>> m.fit_bounds([[52.193636, -2.221575], [52.636878, -1.139759]])
#  |
#  |  keep_in_front(self, *args: folium.map.Layer) -> None
#  |      Pass one or multiple layers that must stay in front.
#  |
#  |      The ordering matters, the last one is put on top.
#  |
#  |      Parameters
#  |      ----------
#  |      *args :
#  |          Variable length argument list. Any folium object that counts as an
#  |          overlay. For example FeatureGroup or TileLayer.
#  |          Does not work with markers, for those use z_index_offset.
#  |
#  |  render(self, **kwargs) -> None
#  |      Renders the HTML representation of the element.
#  |
#  |  show_in_browser(self) -> None
#  |      Display the Map in the default web browser.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  default_css = [('leaflet_css', 'https://cdn.jsdelivr.net/npm/leaflet@1...
#  |
#  |  default_js = [('leaflet', 'https://cdn.jsdelivr.net/npm/leaflet@1.9.3/...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from branca.element.Element:
#  |
#  |  __getstate__(self)
#  |      Modify object state when pickling the object.
#  |
#  |      jinja2 Templates cannot be pickled, so remove the instance attribute
#  |      if it exists. It will be added back when unpickling (see __setstate__).
#  |
#  |  __setstate__(self, state: dict)
#  |      Re-add _template instance attribute when unpickling
#  |
#  |  add_child(self, child, name=None, index=None)
#  |      Add a child.
#  |
#  |  add_children(self, child, name=None, index=None)
#  |      Add a child.
#  |
#  |  add_to(self, parent, name=None, index=None)
#  |      Add element to a parent.
#  |
#  |  get_bounds(self)
#  |      Computes the bounds of the object and all it's children
#  |      in the form [[lat_min, lon_min], [lat_max, lon_max]].
#  |
#  |  get_name(self)
#  |      Returns a string representation of the object.
#  |      This string has to be unique and to be a python and
#  |      javascript-compatible
#  |      variable name.
#  |
#  |  get_root(self)
#  |      Returns the root of the elements tree.
#  |
#  |  save(self, outfile, close_file=True, **kwargs)
#  |      Saves an Element into a file.
#  |
#  |      Parameters
#  |      ----------
#  |      outfile : str or file object
#  |          The file (or filename) where you want to output the html.
#  |      close_file : bool, default True
#  |          Whether the file has to be closed after write.
#  |
#  |  to_dict(self, depth=-1, ordered=True, **kwargs)
#  |      Returns a dict representation of the object.
#  |
#  |  to_json(self, depth=-1, **kwargs)
#  |      Returns a JSON representation of the object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from branca.element.Element:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
import folium

center = [37.559984, 126.9753071] # 숭례문 위도와 경도

# 지도 객체
folium.Map(location=center, zoom_start=16, tiles="OpenRailwayMap")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b54462308812dfbd10827f98bf7c533 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b54462308812dfbd10827f98bf7c533&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b54462308812dfbd10827f98bf7c533 = L.map(
#                 &quot;map_1b54462308812dfbd10827f98bf7c533&quot;,
#                 {
#                     center: [37.559984, 126.9753071],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d59443f115010b1c025fa0221010658 = L.tileLayer(
#                 &quot;https://{s}.tiles.openrailwaymap.org/standard/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map data: \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors | Map style: \u0026copy; \u003ca href=\&quot;https://www.OpenRailwayMap.org\&quot;\u003eOpenRailwayMap\u003c/a\u003e (\u003ca href=\&quot;https://creativecommons.org/licenses/by-sa/3.0/\&quot;\u003eCC-BY-SA\u003c/a\u003e)&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6d59443f115010b1c025fa0221010658.addTo(map_1b54462308812dfbd10827f98bf7c533);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### [실습] : 마커로 위치 표시히기 : folium.Marker()
# * 마커 아이콘 종류: home, info-sign, star, flag, bookmark 등
# * 다른 마커 종류
#     - https://fontawesome.com/icons 사이트에 있는 아이콘 적용, **prefix='fa' 옵션 함께 사용**
#     - https://getbootstrap.com/docs/3.3/components/
# * 마커 색상 :
#     - ['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray']

# %%
# folium.Icon 정보 확인하기
help(folium.Icon)
# Out:
# Help on class Icon in module folium.map:
#
# class Icon(branca.element.MacroElement)
#  |  Icon(color: str = 'blue', icon_color: str = 'white', icon: str = 'info-sign', angle: int = 0, prefix: str = 'glyphicon', **kwargs: Union[str, float, bool, Sequence, dict, NoneType])
#  |
#  |  Creates an Icon object that will be rendered
#  |  using Leaflet.awesome-markers.
#  |
#  |  Parameters
#  |  ----------
#  |  color : str, default 'blue'
#  |      The color of the marker. You can use:
#  |
#  |          ['red', 'blue', 'green', 'purple', 'orange', 'darkred',
#  |           'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue',
#  |           'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen',
#  |           'gray', 'black', 'lightgray']
#  |
#  |  icon_color : str, default 'white'
#  |      The color of the drawing on the marker. You can use colors above,
#  |      or an html color code.
#  |  icon : str, default 'info-sign'
#  |      The name of the marker sign.
#  |      See Font-Awesome website to choose yours.
#  |      Warning : depending on the icon you choose you may need to adapt
#  |      the `prefix` as well.
#  |  angle : int, default 0
#  |      The icon will be rotated by this amount of degrees.
#  |  prefix : str, default 'glyphicon'
#  |      The prefix states the source of the icon. 'fa' for font-awesome or
#  |      'glyphicon' for bootstrap 3.
#  |
#  |  https://github.com/lvoogdt/Leaflet.awesome-markers
#  |
#  |  Method resolution order:
#  |      Icon
#  |      branca.element.MacroElement
#  |      branca.element.Element
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, color: str = 'blue', icon_color: str = 'white', icon: str = 'info-sign', angle: int = 0, prefix: str = 'glyphicon', **kwargs: Union[str, float, bool, Sequence, dict, NoneType])
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {}
#  |
#  |  color_options = {'beige', 'black', 'blue', 'cadetblue', 'darkblue', 'd...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from branca.element.MacroElement:
#  |
#  |  render(self, **kwargs)
#  |      Renders the HTML representation of the element.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from branca.element.Element:
#  |
#  |  __getstate__(self)
#  |      Modify object state when pickling the object.
#  |
#  |      jinja2 Templates cannot be pickled, so remove the instance attribute
#  |      if it exists. It will be added back when unpickling (see __setstate__).
#  |
#  |  __setstate__(self, state: dict)
#  |      Re-add _template instance attribute when unpickling
#  |
#  |  add_child(self, child, name=None, index=None)
#  |      Add a child.
#  |
#  |  add_children(self, child, name=None, index=None)
#  |      Add a child.
#  |
#  |  add_to(self, parent, name=None, index=None)
#  |      Add element to a parent.
#  |
#  |  get_bounds(self)
#  |      Computes the bounds of the object and all it's children
#  |      in the form [[lat_min, lon_min], [lat_max, lon_max]].
#  |
#  |  get_name(self)
#  |      Returns a string representation of the object.
#  |      This string has to be unique and to be a python and
#  |      javascript-compatible
#  |      variable name.
#  |
#  |  get_root(self)
#  |      Returns the root of the elements tree.
#  |
#  |  save(self, outfile, close_file=True, **kwargs)
#  |      Saves an Element into a file.
#  |
#  |      Parameters
#  |      ----------
#  |      outfile : str or file object
#  |          The file (or filename) where you want to output the html.
#  |      close_file : bool, default True
#  |          Whether the file has to be closed after write.
#  |
#  |  to_dict(self, depth=-1, ordered=True, **kwargs)
#  |      Returns a dict representation of the object.
#  |
#  |  to_json(self, depth=-1, **kwargs)
#  |      Returns a JSON representation of the object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from branca.element.Element:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
import folium

center = [37.559984, 126.9753071] # 숭례문 위도와 경도

# 지도 객체
m = folium.Map(location=center, zoom_start=16)
# 지도에 마커 추가하기
folium.Marker(location=center, popup='숭례문', tooltip='우리나라 국보 1호',
              icon=folium.Icon(color='red', icon='info-sign')
              ).add_to(m)
# 다른 곳에서 참고한 icon은 prefix='fa' 옵션을 함께 사용해야 한다.
folium.Marker(location=center, popup='숭례문', tooltip='우리나라 국보 1호',
              icon=folium.Icon(color='red', icon='heart', prefix='fa')
              ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84b8b040c225a8c0b0eac57896302f84 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84b8b040c225a8c0b0eac57896302f84&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84b8b040c225a8c0b0eac57896302f84 = L.map(
#                 &quot;map_84b8b040c225a8c0b0eac57896302f84&quot;,
#                 {
#                     center: [37.559984, 126.9753071],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca4c321239cd18dca0bff7be2e36ed30 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ca4c321239cd18dca0bff7be2e36ed30.addTo(map_84b8b040c225a8c0b0eac57896302f84);
#
#
#             var marker_350045f91a3efe6b45261b4d763a8590 = L.marker(
#                 [37.559984, 126.9753071],
#                 {}
#             ).addTo(map_84b8b040c225a8c0b0eac57896302f84);
#
#
#             var icon_fa541260cd9fbdd0f27cb0305887681f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_350045f91a3efe6b45261b4d763a8590.setIcon(icon_fa541260cd9fbdd0f27cb0305887681f);
#
#
#         var popup_26d1c8346735b685c051e9bf61d9ef4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d125ae3797ab5dd930dfe57e5f38aee = $(`&lt;div id=&quot;html_2d125ae3797ab5dd930dfe57e5f38aee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;숭례문&lt;/div&gt;`)[0];
#                 popup_26d1c8346735b685c051e9bf61d9ef4b.setContent(html_2d125ae3797ab5dd930dfe57e5f38aee);
#
#
#
#         marker_350045f91a3efe6b45261b4d763a8590.bindPopup(popup_26d1c8346735b685c051e9bf61d9ef4b)
#         ;
#
#
#
#
#             marker_350045f91a3efe6b45261b4d763a8590.bindTooltip(
#                 `&lt;div&gt;
#                      우리나라 국보 1호
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b2e0f5119813d962216f9051ae968ae5 = L.marker(
#                 [37.559984, 126.9753071],
#                 {}
#             ).addTo(map_84b8b040c225a8c0b0eac57896302f84);
#
#
#             var icon_db59629fac9d7fe7c1e44fcf99680a9f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b2e0f5119813d962216f9051ae968ae5.setIcon(icon_db59629fac9d7fe7c1e44fcf99680a9f);
#
#
#         var popup_fcdc30996df5e37470154f6874d694a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_20feccc24c7616812e1d19d9279c2697 = $(`&lt;div id=&quot;html_20feccc24c7616812e1d19d9279c2697&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;숭례문&lt;/div&gt;`)[0];
#                 popup_fcdc30996df5e37470154f6874d694a7.setContent(html_20feccc24c7616812e1d19d9279c2697);
#
#
#
#         marker_b2e0f5119813d962216f9051ae968ae5.bindPopup(popup_fcdc30996df5e37470154f6874d694a7)
#         ;
#
#
#
#
#             marker_b2e0f5119813d962216f9051ae968ae5.bindTooltip(
#                 `&lt;div&gt;
#                      우리나라 국보 1호
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### [실습] :  웹 브라우저에 지도 표시하기
# folium 지도를 browser 라이브러리를 사용하여 PC 기본 웹 브라우저로 실행시켜보세요.

# %%
import webbrowser
url = 'https://www.naver.com'
webbrowser.get().open(url) # 기본 브라우저에서 열기
# Out:
# True

# %% [markdown]
# ### [실습] : 특정 웹브라우저로 열기

# %%
# 특정 브라우저를 지정해서 열기
import webbrowser
url = 'https://www.naver.com'

# 엣지 브라우저 실행 앱의 위치 (windows)
# 크롬 브라우저 실행 앱의 위치 지정 (mac)
# 크롬 브라우저 실행 앱의 위치 지정 (windows)
# browser_path = "C:\Program Files (x86)\Microsoft\Edge\Application\msedge.exe" # 엣지 exe 위치
# browser_path = "open - a /Applications/Google\Chrome.app %s"
browser_path = ''
webbrowser.get(browser_path).open(url)

# %% [markdown]
# ### [실습] : folium 지도를 html파일로 저장하고 브라우저에서 열기

# %%
import folium
import os
import platform
import subprocess
import webbrowser

# 지도 중심좌표 지정하기
center = [37.559984, 126.9753071] # 숭례문 위도와 경도
# 지도 객체 만들기
m = folium.Map(location=center, zoom_start=16)
# 지도에 마커로 표시하기
folium.Marker(location=center, popup='<pre> 숭례문 </pre>', tooltip='우리나라 국보 1호',
              icon=folium.Icon(color='red', icon='camera', prefix='fa')
              ).add_to(m)
m

# 지도를 웹 브라우저로 실행시키기
# - 지도를 html 파일로 저장하기
# - 브라우저에서는 html 파일의 전체 경로(fullpath)를 사용해야 오류가 없다.
file = 'map.html'
file = os.path.join(os.getcwd(), file) # 현재 위치 경로 가져오기

m.save(file) # 지도를 html 파일로 저장하기

# macOS에서는 open 명령어로 파일 열기
if platform.system() == "Darwin":
    subprocess.call(['open', file])
else:
    webbrowser.get().open(file)

# %%
# 윈도우에서
import os
import webbrowser

file = 'map.html'
file = os.getcwd().replace('\\', "/") + file    # 현재 위치 경로 가져오기
m.save(file)                                    # 지도를 html 파일로 저장하기

webbrowser.get().open(file)

# %% [markdown]
# ### [실습] : 클릭한 위치에 마커 표시하기
# - ClickForMarker() : 클릭한 위치에 마커 표시하기
# - LatLngPopup() :  위도와 경도 표시하기

# %%
import folium

# 지도 중심좌표 지정하기
center = [37.559984, 126.9753071] # 숭례문 위도와 경도
# 지도 객체 만들기
m = folium.Map(location=center, zoom_start=16)
# 지도에 마커로 표시하기
folium.Marker(location=center, popup='<pre> 숭례문 </pre>', tooltip='우리나라 국보 1호',
              icon=folium.Icon(color='red', icon='camera', prefix='fa')
              ).add_to(m)
# 클릭한 위치에 마커 추가
m.add_child(folium.ClickForMarker(popup='클릭'))
# 위도와 경도 표시하기
m.add_child(folium.LatLngPopup())

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f9def6062491f49f3057b0cf0d62d57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f9def6062491f49f3057b0cf0d62d57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f9def6062491f49f3057b0cf0d62d57 = L.map(
#                 &quot;map_3f9def6062491f49f3057b0cf0d62d57&quot;,
#                 {
#                     center: [37.559984, 126.9753071],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_47e642c0fccd8c013ec1f16c9eaf1689 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_47e642c0fccd8c013ec1f16c9eaf1689.addTo(map_3f9def6062491f49f3057b0cf0d62d57);
#
#
#             var marker_4fcec71519a7b5a5d999b6ba359a99c9 = L.marker(
#                 [37.559984, 126.9753071],
#                 {}
#             ).addTo(map_3f9def6062491f49f3057b0cf0d62d57);
#
#
#             var icon_5963b688ea021e101c9041461776f516 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4fcec71519a7b5a5d999b6ba359a99c9.setIcon(icon_5963b688ea021e101c9041461776f516);
#
#
#         var popup_04b31a3f6ff20db3200f1edbefdd326a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7dd967973c81e5bbf77fe4aadc274324 = $(`&lt;div id=&quot;html_7dd967973c81e5bbf77fe4aadc274324&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt; 숭례문 &lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_04b31a3f6ff20db3200f1edbefdd326a.setContent(html_7dd967973c81e5bbf77fe4aadc274324);
#
#
#
#         marker_4fcec71519a7b5a5d999b6ba359a99c9.bindPopup(popup_04b31a3f6ff20db3200f1edbefdd326a)
#         ;
#
#
#
#
#             marker_4fcec71519a7b5a5d999b6ba359a99c9.bindTooltip(
#                 `&lt;div&gt;
#                      우리나라 국보 1호
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#                 function newMarker(e){
#                     var new_mark = L.marker().setLatLng(e.latlng).addTo(map_3f9def6062491f49f3057b0cf0d62d57);
#                     new_mark.dragging.enable();
#                     new_mark.on(&#x27;dblclick&#x27;, function(e){ map_3f9def6062491f49f3057b0cf0d62d57.removeLayer(e.target)})
#                     var lat = e.latlng.lat.toFixed(4),
#                        lng = e.latlng.lng.toFixed(4);
#                     new_mark.bindPopup(`클릭`);
#                     };
#                 map_3f9def6062491f49f3057b0cf0d62d57.on(&#x27;click&#x27;, newMarker);
#
#
#                 var lat_lng_popup_6458c717f539c9ade083235be66b90bd = L.popup();
#                 function latLngPop(e) {
#                     lat_lng_popup_6458c717f539c9ade083235be66b90bd
#                         .setLatLng(e.latlng)
#                         .setContent(&quot;Latitude: &quot; + e.latlng.lat.toFixed(4) +
#                                     &quot;&lt;br&gt;Longitude: &quot; + e.latlng.lng.toFixed(4))
#                         .openOn(map_3f9def6062491f49f3057b0cf0d62d57);
#                     }
#                 map_3f9def6062491f49f3057b0cf0d62d57.on(&#x27;click&#x27;, latLngPop);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### [실습] 팝업에 유튜브 영상 표시하기
# - 웹브라우저를 사용할 겨우 유튜브 링크(공유>퍼가기)를 넣을 수 있다.

# %%
import folium
import os
import subprocess

# 지도 중심좌표 지정하기
center = [37.559984, 126.9753071] # 숭례문 위도와 경도
# 지도 객체 만들기
m = folium.Map(location=center, zoom_start=16)
# 마커에 유튜브 링크 넣기(html iframe 태그 사용)
folium.Marker(location=center, max_width=200,
              popup='<iframe width="560" height="315" src="https://www.youtube.com/embed/xke5cTEjO2Q?si=IqHeRT8imMm1YnB4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>',
              icon=folium.Icon(color='red', icon='vidio', prefix='fa')
              ).add_to(m)
m

file = 'map.html'
file = os.path.join(os.getcwd(), file)
m.save(file)
subprocess.call(['open', file])
# Out:
# 0

# %% [markdown]
# ### [실습문제]
# 다음 조건이 만족하도록 자신이 여행가고 싶은 장소(국내외)를 지도에 표시해 보세요.
# * 조건1: 각 **장소의 이름을 툴팁(tooltip)으로 표시**하기
# * 조건2: 각 장소의 **마커 아이콘 색상이 다르게 표시**하기
# * 조건3: 각 장소의 **마커 이미지가 다르게 표시**하기
# * 조건4: 각 장소의 **소개 유튜브 영상을 팝업으로 표시**하기
# * ex)
#     - 영국-내셔널 갤러리: 51.508929,-0.128299
#     - 뉴욕-브로드웨이: 40.8124199,-73.9627283
#     - 로마-트레비 분수: 41.9010333,12.4810789

# %%
buckets = {"영국-내셔널 갤러리": (51.508929,-0.128299), "뉴욕-브로드웨이":(40.8124199,-73.9627283), "로마-트레비 분수":(41.9010333,12.4810789)}
icons  = ['star','cloud','camera']
colors = ['red', 'blue', 'green']
youtube = {'영국-내셔널 갤러리':'<iframe width="560" height="315" src="https://www.youtube.com/embed/ZUg3XbExz3k?si=QSRGMCqTFLI-nnaf" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>',
          '뉴욕-브로드웨이':'<iframe width="560" height="315" src="https://www.youtube.com/embed/Z4zAthtkuGQ?si=TuudMAPTs1FPjwRs" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>',
          '로마-트레비 분수':'<iframe width="560" height="315" src="https://www.youtube.com/embed/rxQZLk__jS4?si=X6u5LYk8dWC05VHv" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>'}

import folium

# 지도 객체 만들기
m = folium.Map(location=(22.126554, -38.645050), zoom_start=2)

# 지도에 마커 표시하기 : for 반복문을 이용할 수 있다.
for idx, bucket in enumerate(buckets):
  folium.Marker(location=buckets[bucket], max_width = 200,
                popup=youtube[bucket],
                icon=folium.Icon(color=colors[idx], icon=icons[idx])
                ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fba2a2ff2977acc278e16ad04e176de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fba2a2ff2977acc278e16ad04e176de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fba2a2ff2977acc278e16ad04e176de = L.map(
#                 &quot;map_5fba2a2ff2977acc278e16ad04e176de&quot;,
#                 {
#                     center: [22.126554, -38.64505],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f29057e0bd5f3336beec6672f44517d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f29057e0bd5f3336beec6672f44517d6.addTo(map_5fba2a2ff2977acc278e16ad04e176de);
#
#
#             var marker_57d4ad8f58b787b662018937bca54df1 = L.marker(
#                 [51.508929, -0.128299],
#                 {&quot;maxWidth&quot;: 200}
#             ).addTo(map_5fba2a2ff2977acc278e16ad04e176de);
#
#
#             var icon_f7364518cd241e51f3833ffa440e32d9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_57d4ad8f58b787b662018937bca54df1.setIcon(icon_f7364518cd241e51f3833ffa440e32d9);
#
#
#         var popup_46cf455f16b9b532235a663c766868e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ad3d69c9ac9c1a56983ed3464078cb08 = $(`&lt;div id=&quot;html_ad3d69c9ac9c1a56983ed3464078cb08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;iframe width=&quot;560&quot; height=&quot;315&quot; src=&quot;https://www.youtube.com/embed/ZUg3XbExz3k?si=QSRGMCqTFLI-nnaf&quot; title=&quot;YouTube video player&quot; frameborder=&quot;0&quot; allow=&quot;accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share&quot; referrerpolicy=&quot;strict-origin-when-cross-origin&quot; allowfullscreen&gt;&lt;/iframe&gt;&lt;/div&gt;`)[0];
#                 popup_46cf455f16b9b532235a663c766868e9.setContent(html_ad3d69c9ac9c1a56983ed3464078cb08);
#
#
#
#         marker_57d4ad8f58b787b662018937bca54df1.bindPopup(popup_46cf455f16b9b532235a663c766868e9)
#         ;
#
#
#
#
#             var marker_0e2d2cc4d9091b09067965bd4938163f = L.marker(
#                 [40.8124199, -73.9627283],
#                 {&quot;maxWidth&quot;: 200}
#             ).addTo(map_5fba2a2ff2977acc278e16ad04e176de);
#
#
#             var icon_324fa2c63af010a593b034187be46716 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0e2d2cc4d9091b09067965bd4938163f.setIcon(icon_324fa2c63af010a593b034187be46716);
#
#
#         var popup_08e754506c84c904c064047bc07aa930 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0bae24c41e64ce8dcd6e2eb808e41cd9 = $(`&lt;div id=&quot;html_0bae24c41e64ce8dcd6e2eb808e41cd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;iframe width=&quot;560&quot; height=&quot;315&quot; src=&quot;https://www.youtube.com/embed/Z4zAthtkuGQ?si=TuudMAPTs1FPjwRs&quot; title=&quot;YouTube video player&quot; frameborder=&quot;0&quot; allow=&quot;accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share&quot; referrerpolicy=&quot;strict-origin-when-cross-origin&quot; allowfullscreen&gt;&lt;/iframe&gt;&lt;/div&gt;`)[0];
#                 popup_08e754506c84c904c064047bc07aa930.setContent(html_0bae24c41e64ce8dcd6e2eb808e41cd9);
#
#
#
#         marker_0e2d2cc4d9091b09067965bd4938163f.bindPopup(popup_08e754506c84c904c064047bc07aa930)
#         ;
#
#
#
#
#             var marker_5329149a75f5388c2bd26917904278eb = L.marker(
#                 [41.9010333, 12.4810789],
#                 {&quot;maxWidth&quot;: 200}
#             ).addTo(map_5fba2a2ff2977acc278e16ad04e176de);
#
#
#             var icon_cef349a72f7ff58bd410d2436d51613c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5329149a75f5388c2bd26917904278eb.setIcon(icon_cef349a72f7ff58bd410d2436d51613c);
#
#
#         var popup_4e5bb4bf10d48b072298c8e5baa00033 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec7e56fa9bcbff2f140d

# %%
import folium
import subprocess
import os

buckets = {'영국-내셔널 갤러리':[ [51.508929,-0.128299], '<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/ZUg3XbExz3k?si=5LhG5b5wGLgeErMN" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>'],
           '뉴욕-브로드웨이': [[40.8124199,-73.9627283], '<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/0sG0AaPYuuI?si=ENUVVhCqkfVC5IzB" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>'],
           '로마-트레비 분수':[ [41.9010333,12.4810789], '<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/rxQZLk__jS4?si=x2Zmlt9JoDDE4csa" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>'],
           '페루-마추피추' : [[-13.1631412, -72.5449629], '<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/jkHmgJNx_hU?si=SCSxZXPu41vEQ8NO" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>'],
           '탄자니아-잔지바르섬': [[-6.2642807, 39.4450378], '<iframe width="560" height="315" src="https://www.youtube-nocookie.com/embed/32KGPj1EWk8?si=D-J2mrRw3rNbqd0h" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>']
          }
icons  = ['star','cloud','info-sign','camera','glyphicon glyphicon-thumbs-up']
colors = ['red', 'purple', 'blue', 'green','pink']


# 지도 객체 만들기
m = folium.Map(location= [41.9010333, 12.4810789], 
               zoom_start=2, 
               tiles="cartodbpositron")


# 지도에 마커 표시하기 : for 반복문을 이용할 수 있다.
idx = 0 
for key, value in buckets.items():
    folium.Marker(location= value[0],
        tooltip=key,
        popup=value[1],        
        icon=folium.Icon(icon=icons[idx],
        color=colors[idx], icon_color='white'),
    ).add_to(m)
    idx += 1
    

file = 'map_mytravel.html'
file = os.path.join(os.getcwd(), file)
m.save(file)
subprocess.call(['open', file])
# Out:
# 0

# %% [markdown]
# ### [실습] 지도에 원 반경 표시하기 : folium.Circle(), folium.CircleMarker()
# - folium.Circle()
# - folium.CircleMarker() : 지도 크기 변경에 영향을 받지 않고 원이 유지된다.

# %%
import folium

# 지도에 중심좌표 지정하기
center = [37.559984, 126.9753071] # 숭례문 위도와 경도

# 지도 객체 만들기
m = folium.Map(location=center, zoom_start=15)

folium.Marker(location= center, 
              popup= '<pre> 숭례문 </pre>',
              tooltip= '우리나라 국보 1호',
              icon=folium.Icon(color='red', icon='camera', prefix='fa')
              ).add_to(m)

folium.Marker(location= [37.555946, 126.972317],
              popup= '<pre> 서울역 </pre>',
              tooltip= '서울역',
              icon= folium.Icon(color='black', icon='fa-solid fa-users', prefix='fa-solid')
              ).add_to(m)

folium.Circle(location= center,
              radius= 200,
              color= '#eb9e34',
              fill_color= 'red',
              popup= 'Circle',
              tooltip= '숭례문 관광지'
              ).add_to(m)

folium.CircleMarker(
    [37.555946, 126.972317],
    radius= 100,
    color = 'green',
    fill_color = 'green',
    popup= 'Circle',
    tooltip= '서울역세권'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4fca613dadbd1ce1fd434c8d2a90ada5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4fca613dadbd1ce1fd434c8d2a90ada5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4fca613dadbd1ce1fd434c8d2a90ada5 = L.map(
#                 &quot;map_4fca613dadbd1ce1fd434c8d2a90ada5&quot;,
#                 {
#                     center: [37.559984, 126.9753071],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a75a0760c4a996ddcee68e96ee4de64 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0a75a0760c4a996ddcee68e96ee4de64.addTo(map_4fca613dadbd1ce1fd434c8d2a90ada5);
#
#
#             var marker_d8b8da93208d77b32283f54e26b7eca6 = L.marker(
#                 [37.559984, 126.9753071],
#                 {}
#             ).addTo(map_4fca613dadbd1ce1fd434c8d2a90ada5);
#
#
#             var icon_6794be3465e8e941430478b72f5cee2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;camera&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d8b8da93208d77b32283f54e26b7eca6.setIcon(icon_6794be3465e8e941430478b72f5cee2e);
#
#
#         var popup_77fb2e470f16ab4b9bce8ca93c67b283 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c0d28c7df3fd78236ec3d5e29345c678 = $(`&lt;div id=&quot;html_c0d28c7df3fd78236ec3d5e29345c678&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt; 숭례문 &lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_77fb2e470f16ab4b9bce8ca93c67b283.setContent(html_c0d28c7df3fd78236ec3d5e29345c678);
#
#
#
#         marker_d8b8da93208d77b32283f54e26b7eca6.bindPopup(popup_77fb2e470f16ab4b9bce8ca93c67b283)
#         ;
#
#
#
#
#             marker_d8b8da93208d77b32283f54e26b7eca6.bindTooltip(
#                 `&lt;div&gt;
#                      우리나라 국보 1호
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b792fbac4cbe0413beccb24f0c35f960 = L.marker(
#                 [37.555946, 126.972317],
#                 {}
#             ).addTo(map_4fca613dadbd1ce1fd434c8d2a90ada5);
#
#
#             var icon_b0342f9bd8a93743575ce3dd15472e2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-users&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_b792fbac4cbe0413beccb24f0c35f960.setIcon(icon_b0342f9bd8a93743575ce3dd15472e2e);
#
#
#         var popup_2a36223795f7a3686d72adc6cbda3685 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_14ebb19e1c14a608595534cd8ea062ec = $(`&lt;div id=&quot;html_14ebb19e1c14a608595534cd8ea062ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt; 서울역 &lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_2a36223795f7a3686d72adc6cbda3685.setContent(html_14ebb19e1c14a608595534cd8ea062ec);
#
#
#
#         marker_b792fbac4cbe0413beccb24f0c35f960.bindPopup(popup_2a36223795f7a3686d72adc6cbda3685)
#         ;
#
#
#
#
#             marker_b792fbac4cbe0413beccb24f0c35f960.bindTooltip(
#                 `&lt;div&gt;
#                      서울역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_384f0b0232d3398c58f29e8fd4df8a59 = L.circle(
#                 [37.559984, 126.9753071],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#eb9e34&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4fca613dadbd1ce1fd434c8d2a90ada5);
#
#
#         var popup_1a4fc8685397bb7d20d4d9f5becb7988 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_002b9eacf057dbc430991b31f807805f = $(`&lt;div id=&quot;html_002b9eacf057dbc430991b31f807805f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Circle&lt;/div&gt;`)[0];
#                 popup_1a4fc8685397bb7d20d4d9f5becb7988.setContent(html_002b9eacf057dbc430991b31f807805f);
#
#
#
#         circle_384f0b0232d3398c58f29e8fd4df8a59.bindPopup(popup_1a4fc8685397bb7d

# %% [markdown]
# ### [실습] : 파일 읽어와 위치정보를 마커로 지도에 표시하기
# **자신이 속한 시도의 중학교와 고등학교 지도에 마커로 표시하기**

# %%
import pandas as pd
import folium
import os
import subprocess

'''
파일 가져와 pandas 데이터로 만들기
- 전국 초중고 위치 정보 가져오기
- 자신이 속한 시도의 중학교와 고등하교 정보 가져오기
'''
file = 'geo_data/전국초중등학교위치표준데이터.csv'
df = pd.read_csv(file, encoding='cp949')
df = df.query(" 소재지지번주소.str.contains('서울특별시') and 학교급구분 in ('중학교', '고등학교') ")
print(f'자신이 속한 시도의 중학교와 고등학교 개수: {len(df)}')
df.head(2)

'''
지도 객체 만들어서 마커로 표시하기
- 자신이 속한 시도의 중학교와 고등학교 위치 마커로 표시하기
- 중학교와 고등학교 마커 아이콘 다르게 구분하기
'''
center = [37.549328, 126.8513969] # 강서여성인력개발센터
m = folium.Map(location=center, zoom_start=14)

folium.Marker(location= center,
              popup= '<pre> 강서여성인력개발센터 </pre>',
              tooltip= '강서여성인력개발센터',
              icon= folium.Icon(color='pink', icon='heart', prefix='fa')
              ).add_to(m)

folium.CircleMarker(
    [37.549328, 126.8513969],
    radius= 200,
    color= 'yellow',
    fill_color= 'yellow',
    popup= 'Circle',
    tooltip= '강서여성인력개발센터 근처'
).add_to(m)

for idx in df.index: # DataFrame 한 행씩 읽어오기
    if df.loc[idx, '학교급구분'] == '중학교':
        v_iconcolor = 'green'
    else:
        v_iconcolor = 'blue'

    # 지도에 마커 추가하기
    folium.Marker(location= [df.loc[idx,'위도'], df.loc[idx,'경도']],
                  popup= df.loc[idx,'학교명'],
                  icon= folium.Icon(icon='fa-solid fa-user',
                                    color=v_iconcolor, icon_color='white', prefix='fa-solid'),
                ).add_to(m)

m
# Out:
# 자신이 속한 시도의 중학교와 고등학교 개수: 709
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29f4b3c899b977f26703d0c02f0f05cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29f4b3c899b977f26703d0c02f0f05cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29f4b3c899b977f26703d0c02f0f05cc = L.map(
#                 &quot;map_29f4b3c899b977f26703d0c02f0f05cc&quot;,
#                 {
#                     center: [37.549328, 126.8513969],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_676b904d651fd154aa241299c10e96ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_676b904d651fd154aa241299c10e96ac.addTo(map_29f4b3c899b977f26703d0c02f0f05cc);
#
#
#             var marker_600de656dcdda7503abba7b4efd2329b = L.marker(
#                 [37.549328, 126.8513969],
#                 {}
#             ).addTo(map_29f4b3c899b977f26703d0c02f0f05cc);
#
#
#             var icon_2abdf2e8d99aa4a5cd7677c4c4f027a0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_600de656dcdda7503abba7b4efd2329b.setIcon(icon_2abdf2e8d99aa4a5cd7677c4c4f027a0);
#
#
#         var popup_9e7a707089fb33b8f54c052d42fdeaab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f819e179fa772c01e3300915bf3f7b6f = $(`&lt;div id=&quot;html_f819e179fa772c01e3300915bf3f7b6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt; 강서여성인력개발센터 &lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_9e7a707089fb33b8f54c052d42fdeaab.setContent(html_f819e179fa772c01e3300915bf3f7b6f);
#
#
#
#         marker_600de656dcdda7503abba7b4efd2329b.bindPopup(popup_9e7a707089fb33b8f54c052d42fdeaab)
#         ;
#
#
#
#
#             marker_600de656dcdda7503abba7b4efd2329b.bindTooltip(
#                 `&lt;div&gt;
#                      강서여성인력개발센터
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_6307cce3c11e9689c2b9149ab02480aa = L.circleMarker(
#                 [37.549328, 126.8513969],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_29f4b3c899b977f26703d0c02f0f05cc);
#
#
#         var popup_c0f7478e4e1dd76ecc40cc343ec5229c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6db2fff62b6656a583dcf5254333d5fd = $(`&lt;div id=&quot;html_6db2fff62b6656a583dcf5254333d5fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Circle&lt;/div&gt;`)[0];
#                 popup_c0f7478e4e1dd76ecc40cc343ec5229c.setContent(html_6db2fff62b6656a583dcf5254333d5fd);
#
#
#
#         circle_marker_6307cce3c11e9689c2b9149ab02480aa.bindPopup(popup_c0f7478e4e1dd76ecc40cc343ec5229c)
#         ;
#
#
#
#
#             circle_marker_6307cce3c11e9689c2b9149ab02480aa.bindTooltip(
#                 `&lt;div&gt;
#                      강서여성인력개발센터 근처
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bb2c78ba8447aed33dd690196b81b2d9 = L.marker(
#                 [37.50945384, 127.0738473],
#                 {}
#             ).addTo(map_29f4b3c899b977f26703d0c02f0f05cc);
#
#
#             var icon_fb1dccb049ab857c5cd4b2f9af722895 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-user&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_bb2c78ba8447aed33dd690196b81b2d9.setIcon(icon_fb1dccb049ab857c5cd4b2f9af722895);
#
#
#         var popup_21912acecafc92adf7557a0b75570c6a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_373ab1c5e3d53f72c58ce4f768352fad = $(`&lt;div id=&quot;html_373ab1c5e3d53f72c58ce4f768352fad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;정신여자고등학교&lt;/div&gt;`)[0];
#                 popup_21912acecafc92adf7557a0b75570c6a.setContent(html_373ab1c5e3d53f72c58ce4f768352fad);
#
#
#
#         marker_bb2c78ba8447aed33dd690196b81b2d9.bindP

# %% [markdown]
# ### [실습] : 마커 클러스터로 표시하기 : MarkerCluster()
# 앞에서 표시한 **마커를 클러스터로 표시**하기
# - 참고 : https://python-visualization.github.io/folium/latest/user_guide/plugins/marker_cluster.html

# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster
import os
import subprocess
import webbrowser

file = 'geo_data/전국초중등학교위치표준데이터.csv'
df = pd.read_csv(file, encoding='cp949')
df = df.query(" 소재지지번주소.str.contains('서울특별시') and 학교급구분 in ('중학교', '고등학교') ")
print(f'자신이 속한 시도의 중학교와 고등학교 개수: {len(df)}')

center = [37.549328, 126.8513969] # 강서여성인력개발센터
m = folium.Map(location=center, zoom_start=14) 

folium.Marker(location= center,
              popup= '<pre> 강서여성인력개발센터 </pre>',
              tooltip= '강서여성인력개발센터',
              icon= folium.Icon(color='pink', icon='heart', prefix='fa')
              ).add_to(m)

folium.CircleMarker(
    [37.549328, 126.8513969],
    radius=200,
    color='yellow',
    fill_color='yellow',
    popup='Circle',
    tooltip='강서여성인력개발센터 근처'
).add_to(m)

'''
마커 클러스터 객체 만들기
'''
marker_cluster = MarkerCluster().add_to(m)

# 마커 클러스터 추가하기
for idx in df.index: # DataFrame 한 행씩 읽어오기
    if df.loc[idx,'학교급구분'] == '중학교':
        v_iconcolor = 'green'
    else:
        v_iconcolor = 'blue'

    # 지도에 마커 추가하기
    folium.Marker(location= [df.loc[idx,'위도'], df.loc[idx,'경도']],
                  popup= df.loc[idx,'학교명'],
                  icon= folium.Icon(icon='fa-solid fa-user',
                                    color=v_iconcolor, icon_color='white', prefix='fa-solid'),
                ).add_to(marker_cluster)

# html 파일 저장하고 열기
file = 'map_school_cluster.html'
file = os.path.join(os.getcwd(), file)
m.save(file)
subprocess.call(['open', file])
# webbrowser.get().open(file) # 윈도우에서 열기
# Out:
# 자신이 속한 시도의 중학교와 고등학교 개수: 709
# 0

# %% [markdown]
# https://www.google.co.kr/maps/place/%EC%84%9C%EC%9A%B8%ED%8A%B9%EB%B3%84%EC%8B%9C%EC%B2%AD/data=!3m1!4b1!4m6!3m5!1s0x357ca2f332cb082b:0xe92b70ac420cf0a8!8m2!3d37.5665851!4d126.9782038!16s%2Fm%2F03ylsqy?hl=ko&entry=ttu

# %%
# 내가 졸업한 학교 찾아보기
my_school = df.query(" 학교명 in ('한강중학교', '보성여자고등학교') ")
center = [37.5665851, 126.9782038] # 서울시청의 위도와 경도

m_my_school = folium.Map(location=center, zoom_start=10)

folium.Marker(location=center, popup='서울시청', tooltip='서울시청',
              icon=folium.Icon(color='black', icon='info-sign')
              ).add_to(m_my_school)

for idx in my_school.index:
    folium.Marker(location= [my_school.loc[idx,'위도'], my_school.loc[idx,'경도']],
                  popup= my_school.loc[idx,'학교명'],
                  icon= folium.Icon(icon='fa-solid fa-user',
                                    color='green', icon_color='while', prefix='fa-solid'),
                  ).add_to(m_my_school)

m_my_school
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_949d35f00f6120d800f9020d6ff7039f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_949d35f00f6120d800f9020d6ff7039f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_949d35f00f6120d800f9020d6ff7039f = L.map(
#                 &quot;map_949d35f00f6120d800f9020d6ff7039f&quot;,
#                 {
#                     center: [37.5665851, 126.9782038],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d9f43e148216d64f597b7d598c3d106 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0d9f43e148216d64f597b7d598c3d106.addTo(map_949d35f00f6120d800f9020d6ff7039f);
#
#
#             var marker_6ac973ddf1252b0d8bff39770aea8970 = L.marker(
#                 [37.5665851, 126.9782038],
#                 {}
#             ).addTo(map_949d35f00f6120d800f9020d6ff7039f);
#
#
#             var icon_15aae7616f7aa06b3a3814bcc3d40967 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;black&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6ac973ddf1252b0d8bff39770aea8970.setIcon(icon_15aae7616f7aa06b3a3814bcc3d40967);
#
#
#         var popup_6731c4e1278227fd80f1cec06f2c3055 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_75b04af1a7248093a14bf23c4fdd905a = $(`&lt;div id=&quot;html_75b04af1a7248093a14bf23c4fdd905a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울시청&lt;/div&gt;`)[0];
#                 popup_6731c4e1278227fd80f1cec06f2c3055.setContent(html_75b04af1a7248093a14bf23c4fdd905a);
#
#
#
#         marker_6ac973ddf1252b0d8bff39770aea8970.bindPopup(popup_6731c4e1278227fd80f1cec06f2c3055)
#         ;
#
#
#
#
#             marker_6ac973ddf1252b0d8bff39770aea8970.bindTooltip(
#                 `&lt;div&gt;
#                      서울시청
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4e60876cac2df44b57011f200b557366 = L.marker(
#                 [37.52361192, 126.9927909],
#                 {}
#             ).addTo(map_949d35f00f6120d800f9020d6ff7039f);
#
#
#             var icon_ec6adc31d02ef42c93fd5c189a368c6e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-user&quot;, &quot;iconColor&quot;: &quot;while&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_4e60876cac2df44b57011f200b557366.setIcon(icon_ec6adc31d02ef42c93fd5c189a368c6e);
#
#
#         var popup_90cec8154d04f6fade3f4ef859e0305d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_634c0a29c8aa5a4b66ebd37e9842feed = $(`&lt;div id=&quot;html_634c0a29c8aa5a4b66ebd37e9842feed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;한강중학교&lt;/div&gt;`)[0];
#                 popup_90cec8154d04f6fade3f4ef859e0305d.setContent(html_634c0a29c8aa5a4b66ebd37e9842feed);
#
#
#
#         marker_4e60876cac2df44b57011f200b557366.bindPopup(popup_90cec8154d04f6fade3f4ef859e0305d)
#         ;
#
#
#
#
#             var marker_2478777c86f5d1015112290bc309418c = L.marker(
#                 [37.54308154, 126.9842996],
#                 {}
#             ).addTo(map_949d35f00f6120d800f9020d6ff7039f);
#
#
#             var icon_c67eb35176c202df983eb3de1baccd56 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;fa-solid fa-user&quot;, &quot;iconColor&quot;: &quot;while&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa-solid&quot;}
#             );
#             marker_2478777c86f5d1015112290bc309418c.setIcon(icon_c67eb35176c202df983eb3de1baccd56);
#
#
#         var popup_e8bf0738bec89fe5f93bcf2d49d1338a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f99d392d88aefd0998fe0bf975c41bb9 = $(`&lt;div id=&quot;html_f99d392d88aefd0998fe0bf975c41bb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;보성여자고등학교&lt;/div&gt;`)[0];
#                 popup_e8bf0738bec89fe5f93bcf2d49d1338a.setContent(html_f99d392d88aefd0998fe0bf975c41bb9);
#
#
#
#         marker_2478777c86f5d1015112290bc309418c.bindPopup(popup_e8bf0738bec89fe5f93bcf2d49d1338a)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### [실습문제] : CCTV위치 지도에 표시하기
# * 공공데이터 다운로드 : **서울시 안심이 CCTV연계 현황**
#     - 위치: 공공데이터포털(서울특별시_(안심이) CCTV 설치 현황)->서울 열린데이터 광장
#     - 서울 열린데이터 광장: https://data.seoul.go.kr/dataList/OA-20923/S/1/datasetView.do
#     - 서울시 안심이 CCTV 연계 현황.csv
# * **미션1 : 자신의 집 주소 근처에 위치한 CCTV를 지도에 마커로 표시하기**
# * **미션2 : 미션1을 마커 클러스터로 표시히가**

# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster
import os
import subprocess
import webbrowser

file = 'geo_data/서울시 안심이 CCTV 연계 현황.csv'
df = pd.read_csv(file, encoding='cp949')
df = df.query(" 자치구.str.contains('강서구') and `안심 주소`.str.contains('까치산로') ")
print(f'강서구 & 까치산로 근처 CCTV 개수: {len(df)}')

center = [37.549328, 126.8513969] # 강서여성인력개발센터
m = folium.Map(location= center,
               zoom_start=16)

folium.Marker(location= center,
              popup= '<pre> 강서여성인력개발센터 </pre>',
              tooltip= '강서여성인력개발센터',
              icon= folium.Icon(color='pink', icon='heart', prefix='fa')
              ).add_to(m)

folium.CircleMarker(
    [37.549328, 126.8513969],
    radius=200,
    color='yellow',
    fill_color='yellow',
    popup='Circle',
    tooltip='강서여성인력개발센터 근처'
).add_to(m)

# 마커 클러스터 추가하기
marker_cluster = MarkerCluster().add_to(m)
for idx in df.index:
    if df.loc[idx,'안심 주소']:
        cctv_no = df.loc[idx,'안심 주소'].split('_')[0]

    # 지도에 마커 추가하기
    folium.Marker(location= [df.loc[idx,'위도'], df.loc[idx,'경도']],
                  popup=cctv_no,
                  icon=folium.Icon(icon='video', color='red',
                                   icon_color='white', prefix='fa'),
                  ).add_to(marker_cluster)

m
# Out:
# 강서구 & 까치산로 근처 CCTV 개수: 43
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edbc36d8f565a18d21b58b703ec5f137 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edbc36d8f565a18d21b58b703ec5f137&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edbc36d8f565a18d21b58b703ec5f137 = L.map(
#                 &quot;map_edbc36d8f565a18d21b58b703ec5f137&quot;,
#                 {
#                     center: [37.549328, 126.8513969],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_223b3299d69c03bf75b27dc691d8aedc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_223b3299d69c03bf75b27dc691d8aedc.addTo(map_edbc36d8f565a18d21b58b703ec5f137);
#
#
#             var marker_37c8aec253a97cc9e9994c6d03d193d5 = L.marker(
#                 [37.549328, 126.8513969],
#                 {}
#             ).addTo(map_edbc36d8f565a18d21b58b703ec5f137);
#
#
#             var icon_907083fa7e0b5d88a339a3556291e30a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_37c8aec253a97cc9e9994c6d03d193d5.setIcon(icon_907083fa7e0b5d88a339a3556291e30a);
#
#
#         var popup_5e9e3a90f3744edbfe433baf42e3ee49 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c1f9e8388c54d205b2f8b4288390373 = $(`&lt;div id=&quot;html_5c1f9e8388c54d205b2f8b4288390373&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;pre&gt; 강서여성인력개발센터 &lt;/pre&gt;&lt;/div&gt;`)[0];
#                 popup_5e9e3a90f3744edbfe433baf42e3ee49.setContent(html_5c1f9e8388c54d205b2f8b4288390373);
#
#
#
#         marker_37c8aec253a97cc9e9994c6d03d193d5.bindPopup(popup_5e9e3a90f3744edbfe433baf42e3ee49)
#         ;
#
#
#
#
#             marker_37c8aec253a97cc9e9994c6d03d193d5.bindTooltip(
#                 `&lt;div&gt;
#                      강서여성인력개발센터
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_a7dd9601c493ead6f2b2767d0cd473b6 = L.circleMarker(
#                 [37.549328, 126.8513969],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_edbc36d8f565a18d21b58b703ec5f137);
#
#
#         var popup_239aef4d0951d47f2a29000ae9a97845 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f91e63156826a8dd7c2c452f9b58ecf = $(`&lt;div id=&quot;html_2f91e63156826a8dd7c2c452f9b58ecf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Circle&lt;/div&gt;`)[0];
#                 popup_239aef4d0951d47f2a29000ae9a97845.setContent(html_2f91e63156826a8dd7c2c452f9b58ecf);
#
#
#
#         circle_marker_a7dd9601c493ead6f2b2767d0cd473b6.bindPopup(popup_239aef4d0951d47f2a29000ae9a97845)
#         ;
#
#
#
#
#             circle_marker_a7dd9601c493ead6f2b2767d0cd473b6.bindTooltip(
#                 `&lt;div&gt;
#                      강서여성인력개발센터 근처
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cluster_62526f2bdfa60881e0955574f463d247 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_fa3f006451a139cf901b91dcfff76a0f = L.marker(
#                 [37.5414, 126.8449],
#                 {}
#             ).addTo(marker_cluster_62526f2bdfa60881e0955574f463d247);
#
#
#             var icon_2eb5448c056d599eeac26aa291f126f0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;video&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fa3f006451a139cf901b91dcfff76a0f.setIcon(

# %% [markdown]
# -------------------------

# %% [markdown]
# ## 02.지도에 의미 있는 데이터 분포 표현하기

# %% [markdown]
# ### 지도에 데이터 분포 표시하는 방법
# * folium 지도에 행정구역 경계를 표시하기 위해서는 우선 행정구역의 경계 위치 좌표 값이 표시된  geoJson 데이터가 필요함
# * 대한민국 행정구역 경계 geoJson 파일
#     - 파일 다운로드: https://github.com/southkorea/southkorea-maps  > /kostat/2018/json/
#     - http://www.gisdeveloper.co.kr/?p=2332
#     - 다운로드된 파일 위치 : **C:\python\dataAnalysis\data\geo\** <br>
#     - skorea-provinces-geo.json  (시/도 경계 )
#     - skorea-municipalities-geo.json  (시/군/구 경계)
#     - skorea-submunicipalities-geo.json  (읍/면/동 경계)

# %% [markdown]
# ### [실습] : 우리나라 행정구역 경계 지도에 표시하기 : folium.GeoJson()

# %%
import folium
import json

# 1. GeoJson 파일 불러오기
file = 'skorea-provinces-geo.json' # 대한민국 지도 경계 정보
# file = 'skorea-municipalities-geo.json' # 대한민국 시군구 경계 정보
# file = 'skorea-submunicipalities-geo.json' # 대한민국 읍면동 경계 정보
# file = 'HangJeongDong_ver20230701.geojson' # 대한민국 행정동
# file = 'hangjeongdong_서울특별시.geojson' # 서울특별시 행정동
data = open(file, 'r', encoding='utf-8').read()
geo_data = json.loads(data)

# 2. 지도에 GeoJson 정보를 표현하기
m = folium.Map(location=[37.559984, 126.9753071],
              zoom_start=11)
folium.GeoJson(geo_data, name='json_data').add_to(m)
m

# %% [markdown]
# ### [실습] : 지역별 분포 데이터 만들기 : folium.Choropleth()
# 지역별 구씨 현황 데이터를 지도 영역 데이터와 연결하여 색칠을 통해 데이터 분포 시각화하기
# - 지역별 구씨 현황: family_name_goo.csv(앞에서 생성한 파일)
# - 지도 영역 데이터: skorea-provinces-geo.json

# %%
import pandas as pd
import folium
import json

# 1. 지역별 구씨 정보 가져오기
file = 'geo_data/family_name_goo.csv'
df = pd.read_csv(file, encoding='utf-8')
df.head()

# 2. GeoJson 파일 불러오기
file = 'geo_data/skorea-provinces-geo.json'
data = open(file, 'r', encoding='utf-8').read()
geo_data = json.loads(data)
geo_data

# 3. 지도에 분포 표시하기
m = folium.Map(location=[37.566345, 126.977893], zoom_start=7, tiles='OpenStreetMap')

# 4. 지도 경계별 색상 칠하기
folium.Choropleth(
    geo_data=geo_data,
    name='json_data',
    data=df,
    columns=('지역', '인구'),
    key_on='feature.properties.name',
    fill_color='BuGn',
    legend_name='인구',
).add_to(m)
m

# 5. 데이터 분포 지도를 출력한다.
file = 'geo_data/family_name_goo_map.html'
file = os.path.join(os.getcwd(), file)
m.save(file)
subprocess.call(['open', file])
# Out:
# 0

# %% [markdown]
# -------------------

# %% [markdown]
# ### [실습문제] : 서울특별시 행정구역별 의미 있는 색상 칠하기
# - 참고 : https://github.com/raqoon886/Local_HangJeongDong
# - 행정구역 데이터 : skorea-provinces-geo.json
# - 행정구역별 인구 데이터 : 행정구역별-인구현황.csv
# - 행정구역별 인구 데이터 조회 및 다운로드 : https://jumin.mois.go.kr/ 에서 2022년 데이터 검색

# %% [markdown]
# #### 1. 서울특별시 인구 데이터 전처리하기
# - 전처리 대상 : 202403_202403_주민등록인구및세대현황_월간.csv
# - 전처리 작업 : 행정구역, 전체인구, 남자인구, 여자인구 데이터만 추출하기

# %%
# 1. 서울특별시 인구 데이터 가져오기
import pandas as pd
import json
import folium

file = 'geo_data/202403_202403_주민등록인구및세대현황_월간.csv'
df = pd.read_csv(file, encoding='cp949')

# %%
# 필요한 컬럼만 추출해서 새로운 DataFrame으로 지정하기 : ['행정구역','', '남자인구', '여자인구']
df_t = df[['행정구역', '2024년03월_총인구수', '2024년03월_남자 인구수', '2024년03월_여자 인구수']]
df_t.columns = ['행정구역', 'total', '남자인구', '여자인구']

# %%
# 첫 번째 row 삭제하기
df_t.drop(0, axis=0, inplace=True)
# Out:
# /var/folders/9k/vdhwnv4n6zs1fzzz3xy8666h0000gn/T/ipykernel_2365/4121136929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_t.drop(0, axis=0, inplace=True)

# %%
# 행정구역 시, 시군구 분리하기
df_t.insert(1, 'sido', df_t['행정구역'].str.split(' ').str[0])
df_t.insert(2, '시군구', df_t['행정구역'].str.split(' ').str[2])
df_t.head()
# Out:
#                            행정구역   sido  시군구    total     남자인구     여자인구
# 1  서울특별시 서울특별시 종로구 (1111000000)  서울특별시  종로구  139,498   67,228   72,270
# 2   서울특별시 서울특별시 중구 (1114000000)  서울특별시   중구  121,602   58,767   62,835
# 3  서울특별시 서울특별시 용산구 (1117000000)  서울특별시  용산구  209,849  100,488  109,361
# 4  서울특별시 서울특별시 성동구 (1120000000)  서울특별시  성동구  276,964  134,232  142,732
# 5  서울특별시 서울특별시 광진구 (1121500000)  서울특별시  광진구  335,105  160,888  174,217

# %%
df_t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 1 to 25
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   행정구역    25 non-null     object
#  1   sido    25 non-null     object
#  2   시군구     25 non-null     object
#  3   total   25 non-null     object
#  4   남자인구    25 non-null     object
#  5   여자인구    25 non-null     object
# dtypes: object(6)
# memory usage: 1.3+ KB

# %%
# 문자열 --> 숫자로 변환하기
df_t.loc[:, 'total'] = df_t.loc[:, 'total'].str.replace(',', '').apply('int64')
df_t.loc[:, '남자인구'] = df_t.loc[:, '남자인구'].str.replace(',','').apply('int64')
df_t.loc[:, '여자인구'] = df_t.loc[:, '여자인구'].str.replace(',','').apply('int64')
df_t.head()
# Out:
#                            행정구역   sido  시군구   total    남자인구    여자인구
# 1  서울특별시 서울특별시 종로구 (1111000000)  서울특별시  종로구  139498   67228   72270
# 2   서울특별시 서울특별시 중구 (1114000000)  서울특별시   중구  121602   58767   62835
# 3  서울특별시 서울특별시 용산구 (1117000000)  서울특별시  용산구  209849  100488  109361
# 4  서울특별시 서울특별시 성동구 (1120000000)  서울특별시  성동구  276964  134232  142732
# 5  서울특별시 서울특별시 광진구 (1121500000)  서울특별시  광진구  335105  160888  174217

# %%
# 2. GeoJson 파일 불러오기

# 방법1
geo_data = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'

# 방법2
file = 'geo_data/seoul_geo_simple.json'
data = open(file, 'r', encoding='utf-8').read()
geo_data = json.loads(data)
len(geo_data['features'])
tmp = []
for idx in range(len(geo_data['features'])):
    tmp.append(geo_data['features'][idx]['properties']['name'])
tmp.sort()
tmp

# %%
# 3. 지도에 분포 표시하기
m = folium.Map(location=[37.566345, 126.977893], zoom_start=11, tiles='OpenStreetMap')

# 4. 지도 경계별 색상 칠하기
folium.Choropleth(
    geo_data=geo_data,
    name='인구수',
    data=df_t,
    columns=('시군구', 'total'),
    key_on='feature.properties.name',
    fill_color='BuPu',
    legend_name='total',
    line_weight=2,
    highlight=True
).add_to(m)

# 5. 데이터 분포 지도를 출력
file = 'map_seoul_person.html'
file = os.path.join(os.getcwd(), file)
m.save(file)
subprocess.call(['open', file])
# Out:
# 0

# %% [markdown]
# -----------------------------------------

# %% [markdown]
# THE END
